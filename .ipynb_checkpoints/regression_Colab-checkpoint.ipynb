# %% [markdown]
# <a href="https://colab.research.google.com/github/ApplesDaddy/CMPT353Project/blob/main/regression_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !conda --version
# !which python
# !python --version
# !echo $PYTHONPATH
# Out:
# /bin/bash: line 1: conda: command not found
# /usr/local/bin/python
# Python 3.10.12
# /env/python

# %%
# %env PYTHONPATH=
# !echo $PYTHONPATH
# Out:
# env: PYTHONPATH=

# %%
# most recent install link from https://docs.anaconda.com/free/miniconda/miniconda-other-installer-links/
# !wget https://repo.anaconda.com/miniconda/Miniconda3-py310_24.1.2-0-Linux-x86_64.sh
# !chmod +x Miniconda3-py310_24.1.2-0-Linux-x86_64.sh
# !bash ./Miniconda3-py310_24.1.2-0-Linux-x86_64.sh -b -f -p /usr/local/
# Out:
# --2024-03-25 23:46:31--  https://repo.anaconda.com/miniconda/Miniconda3-py310_24.1.2-0-Linux-x86_64.sh
# Resolving repo.anaconda.com (repo.anaconda.com)... 104.16.131.3, 104.16.130.3, 2606:4700::6810:8203, ...
# Connecting to repo.anaconda.com (repo.anaconda.com)|104.16.131.3|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 134948792 (129M) [application/octet-stream]
# Saving to: ‘Miniconda3-py310_24.1.2-0-Linux-x86_64.sh’
#
# Miniconda3-py310_24 100%[===================>] 128.70M   215MB/s    in 0.6s
#
# 2024-03-25 23:46:32 (215 MB/s) - ‘Miniconda3-py310_24.1.2-0-Linux-x86_64.sh’ saved [134948792/134948792]
#
# PREFIX=/usr/local
# Unpacking payload ...
#
# Installing base environment...
#
#
# Downloading and Extracting Packages:
#
#
# Downloading and Extracting Packages:
#
# done
# done
# installation finished.

# %%
# !which conda
# !conda --version
# !conda install --channel defaults conda python=3.10 --yes
# !conda update --channel defaults --all --yes
# Out:
# /usr/local/bin/conda
# conda 24.1.2
# Channels:
#  - defaults
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#   added / updated specs:
#     - conda
#     - python=3.10
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     archspec-0.2.3             |     pyhd3eb1b0_0          47 KB
#     ca-certificates-2024.3.11  |       h06a4308_0         127 KB
#     conda-24.3.0               |  py310h06a4308_0         957 KB
#     python-3.10.14             |       h955ad1f_0        26.8 MB
#     xz-5.4.6                   |       h5eee18b_0         651 KB
#     ------------------------------------------------------------
#                                            Total:        28.6 MB
#
# The following packages will be UPDATED:
#
#   archspec                               0.2.1-pyhd3eb1b0_0 --> 0.2.3-pyhd3eb1b0_0
#   ca-certificates                     2023.12.12-h06a4308_0 --> 2024.3.11-h06a4308_0
#   conda                              24.1.2-py310h06a4308_0 --> 24.3.0-py310h06a4308_0
#   python                                 3.10.13-h955ad1f_0 --> 3.10.14-h955ad1f_0
#   xz                                       5.4.5-h5eee18b_0 --> 5.4.6-h5eee18b_0
#
#
#
# Downloading and Extracting Packages:
# python-3.10.14       | 26.8 MB   | :   0% 0/1 [00:00<?, ?it/s]
# conda-24.3.0         | 957 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
# xz-5.4.6             | 651 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
# ca-certificates-2024 | 127 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# archspec-0.2.3       | 47 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
# xz-5.4.6             | 651 KB    | :   2% 0.024589524238331082/1 [00:00<00:07,  7.23s/it]
# python-3.10.14       | 26.8 MB   | :   0% 0.0005823992988458442/1 [00:00<05:50, 350.51s/it]
#
#
# ca-certificates-2024 | 127 KB    | :  13% 0.12568368888991172/1 [00:00<00:01,  1.79s/it]
#
#
#
# python-3.10.14       | 26.8 MB   | :  96% 0.9586292459002594/1 [00:00<00:00,  1.77it/s]
#
# xz-5.4.6             | 651 KB    | : 100% 1.0/1 [00:00<00:00,  1.31it/s]
#
# xz-5.4.6             | 651 KB    | : 100% 1.0/1 [00:00<00:00,  1.31it/s]
#
#
# ca-certificates-2024 | 127 KB    | : 100% 1.0/1 [00:00<00:00,  1.22it/s]
#
#
# ca-certificates-2024 | 127 KB    | : 100% 1.0/1 [00:00<00:00,  1.22it/s]
#
#
#
# archspec-0.2.3       | 47 KB     | : 100% 1.0/1 [00:01<00:00,  1.04s/it]
#
#
#
# archspec-0.2.3       | 47 KB     | : 100% 1.0/1 [00:01<00:00,  1.04s/it]
# conda-24.3.0         | 957 KB    | : 100% 1.0/1 [00:01<00:00,  1.12s/it]
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# done
# Channels:
#  - defaults
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     bzip2-1.0.8                |       h5eee18b_5         262 KB
#     cryptography-42.0.5        |  py310hdda0065_0         2.1 MB
#     jsonpatch-1.33             |  py310h06a4308_0          31 KB
#     packaging-23.2             |  py310h06a4308_0         146 KB
#     tzdata-2024a               |       h04d1e81_0         116 KB
#     ------------------------------------------------------------
#                                            Total:         2.6 MB
#
# The following packages will be UPDATED:
#
#   bzip2                                    1.0.8-h7b6447c_0 --> 1.0.8-h5eee18b_5
#   cryptography                       42.0.2-py310hdda0065_0 --> 42.0.5-py310hdda0065_0
#   jsonpatch          pkgs/main/noarch::jsonpatch-1.32-pyhd~ --> pkgs/main/linux-64::jsonpatch-1.33-py310h06a4308_0
#   packaging                            23.1-py310h06a4308_0 --> 23.2-py310h06a4308_0
#   tzdata                                   2023d-h04d1e81_0 --> 2024a-h04d1e81_0
#
#
#
# Downloading and Extracting Packages:
# cryptography-42.0.5  | 2.1 MB    | :   0% 0/1 [00:00<?, ?it/s]
# bzip2-1.0.8          | 262 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
# packaging-23.2       | 146 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
# tzdata-2024a         | 116 KB    | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# jsonpatch-1.33       | 31 KB     | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# jsonpatch-1.33       | 31 KB     | :  51% 0.5135245259363737/1 [00:00<00:00,  2.41it/s]
# cryptography-42.0.5  | 2.1 MB    | :   1% 0.007513318209478686/1 [00:00<00:31, 31.84s/it]
#
# packaging-23.2       | 146 KB    | :  11% 0.10954434526794371/1 [00:00<00:01,  2.23s/it]
#
#
# tzdata-2024a         | 116 KB    | :  14% 0.13760088688071623/1 [00:00<00:01,  1.84s/it]
#
#
#
# jsonpatch-1.33       | 31 KB     | : 100% 1.0/1 [00:00<00:00,  2.41it/s]
# bzip2-1.0.8          | 262 KB    | : 100% 1.0/1 [00:00<00:00,  3.67s/it]
#
# packaging-23.2       | 146 KB    | : 100% 1.0/1 [00:00<00:00,  2.99it/s]
#
# packaging-23.2       | 146 KB    | : 100% 1.0/1 [00:00<00:00,  2.99it/s]
#
#
# tzdata-2024a         | 116 KB    | : 100% 1.0/1 [00:00<00:00,  1.34it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# done

# %%
import sys
sys.path
# Out:
# ['/content',
#  '/env/python',
#  '/usr/lib/python310.zip',
#  '/usr/lib/python3.10',
#  '/usr/lib/python3.10/lib-dynload',
#  '',
#  '/usr/local/lib/python3.10/dist-packages',
#  '/usr/lib/python3/dist-packages',
#  '/usr/local/lib/python3.10/dist-packages/IPython/extensions',
#  '/root/.ipython']

# %%
# !ls /usr/local/lib/python3.10/dist-packages
# Out:
# absl
# absl_py-1.4.0.dist-info
# adbc_driver_duckdb
# aiohttp
# aiohttp-3.9.3.dist-info
# aiosignal
# aiosignal-1.3.1.dist-info
# alabaster
# alabaster-0.7.16.dist-info
# albumentations
# albumentations-1.3.1.dist-info
# altair
# altair-4.2.2.dist-info
# annotated_types
# annotated_types-0.6.0.dist-info
# anyio
# anyio-3.7.1.dist-info
# apiclient
# appdirs-1.4.4.dist-info
# appdirs.py
# apt
# apt_inst.cpython-310-x86_64-linux-gnu.so
# apt_inst-stubs
# apt_pkg.cpython-310-x86_64-linux-gnu.so
# apt_pkg-stubs
# aptsources
# argon2
# argon2_cffi-23.1.0.dist-info
# _argon2_cffi_bindings
# argon2_cffi_bindings-21.2.0.dist-info
# array_record
# array_record-0.5.0.dist-info
# arviz
# arviz-0.15.1.dist-info
# astropy
# astropy-5.3.4.dist-info
# astunparse
# astunparse-1.6.3.dist-info
# async_timeout
# async_timeout-4.0.3.dist-info
# atpublic-4.0.dist-info
# attr
# attrs
# attrs-23.2.0.dist-info
# audioread
# audioread-3.0.1.dist-info
# AUTHORS.rst
# autograd
# autograd-1.6.2.dist-info
# babel
# Babel-2.14.0.dist-info
# backcall
# backcall-0.2.0.dist-info
# beautifulsoup4-4.12.3.dist-info
# bidict
# bidict-0.23.1.dist-info
# bigframes
# bigframes-0.26.0.dist-info
# bigframes_vendored
# bin
# bleach
# bleach-6.1.0.dist-info
# blis
# blis-0.7.11.dist-info
# blosc2
# blosc2-2.0.0.dist-info
# bokeh
# bokeh-3.3.4.dist-info
# box
# bqplot
# bqplot-0.12.43.dist-info
# branca
# branca-0.7.1.dist-info
# bs4
# build
# build-1.1.1.dist-info
# cachecontrol
# cachecontrol-0.14.0.dist-info
# cachetools
# cachetools-5.3.3.dist-info
# catalogue
# catalogue-2.0.10.dist-info
# certifi
# certifi-2024.2.2.dist-info
# cffi
# cffi-1.16.0.dist-info
# _cffi_backend.cpython-310-x86_64-linux-gnu.so
# chardet
# chardet-5.2.0.dist-info
# charset_normalizer
# charset_normalizer-3.3.2.dist-info
# chex
# chex-0.1.86.dist-info
# clang
# click
# click-8.1.7.dist-info
# click_plugins
# click_plugins-1.1.1.dist-info
# cligj
# cligj-0.7.2.dist-info
# cloudpathlib
# cloudpathlib-0.16.0.dist-info
# cloudpickle
# cloudpickle-2.2.1.dist-info
# cmake
# cmake-3.27.9.dist-info
# cmdstanpy
# cmdstanpy-1.2.1.dist-info
# colab_kernel_launcher.py
# colorcet
# colorcet-3.1.0.dist-info
# colorlover
# colorlover-0.3.0.dist-info
# colour-0.1.5.dist-info
# colour.py
# community
# community-1.0.0b1.dist-info
# confection
# confection-0.1.4.dist-info
# cons
# cons-0.4.6.dist-info
# contextlib2
# contextlib2-21.6.0.dist-info
# contourpy
# contourpy-1.2.0.dist-info
# cpuinfo
# cryptography
# cryptography-42.0.5.dist-info
# cufflinks
# cufflinks-0.17.3.dist-info
# cupy
# cupy_backends
# cupy_cuda12x-12.2.0.dist-info
# cupyx
# cv2
# _cvxcore.cpython-310-x86_64-linux-gnu.so
# cvxopt
# cvxopt-1.3.2.dist-info
# cvxopt.libs
# cvxpy
# cvxpy-1.3.3.dist-info
# cycler
# cycler-0.12.1.dist-info
# cymem
# cymem-2.0.8.dist-info
# Cython
# Cython-3.0.9.dist-info
# cython.py
# dask
# dask-2023.8.1.dist-info
# datascience
# datascience-0.17.6.dist-info
# dateutil
# db_dtypes
# db_dtypes-1.2.0.dist-info
# debugpy
# debugpy-1.6.6.dist-info
# decorator-4.4.2.dist-info
# decorator.py
# defusedxml
# defusedxml-0.7.1.dist-info
# distributed
# distributed-2023.8.1.dist-info
# _distutils_hack
# distutils-precedence.pth
# distutils-stubs
# dlib
# dlib-19.24.2.dist-info
# _dlib_pybind11.cpython-310-x86_64-linux-gnu.so
# dm_tree-0.1.8.dist-info
# doc
# docs
# docutils
# docutils-0.18.1.dist-info
# dopamine
# dopamine_rl-4.0.6.dist-info
# dot_parser.py
# duckdb
# duckdb-0.9.2.dist-info
# duckdb-stubs
# earthengine_api-0.1.394.dist-info
# easydict
# easydict-1.13.dist-info
# ecos
# ecos-2.0.13.dist-info
# _ecos.cpython-310-x86_64-linux-gnu.so
# editdistance
# editdistance-0.6.2.dist-info
# ee
# eerepr
# eerepr-0.0.4.dist-info
# en_core_web_sm
# en_core_web_sm-3.7.1.dist-info
# entrypoints-0.4.dist-info
# entrypoints.py
# erfa
# etils
# etils-1.7.0.dist-info
# etuples
# etuples-0.3.9.dist-info
# et_xmlfile
# et_xmlfile-1.1.0.dist-info
# exceptiongroup
# exceptiongroup-1.2.0.dist-info
# extension
# fastai
# fastai-2.7.14.dist-info
# fastcore
# fastcore-1.5.29.dist-info
# fastdownload
# fastdownload-0.0.7.dist-info
# fastjsonschema
# fastjsonschema-2.19.1.dist-info
# fastprogress
# fastprogress-1.0.3.dist-info
# fastrlock
# fastrlock-0.8.2.dist-info
# filelock
# filelock-3.13.1.dist-info
# fiona
# fiona-1.9.6.dist-info
# fiona.libs
# firebase_admin
# firebase_admin-5.3.0.dist-info
# flask
# Flask-2.2.5.dist-info
# flatbuffers
# flatbuffers-24.3.7.dist-info
# flax
# flax-0.8.2.dist-info
# folium
# folium-0.14.0.dist-info
# fontTools
# fonttools-4.50.0.dist-info
# frozendict
# frozendict-2.4.0.dist-info
# frozenlist
# frozenlist-1.4.1.dist-info
# fsspec
# fsspec-2023.6.0.dist-info
# functorch
# future
# future-0.18.3.dist-info
# gast
# gast-0.5.4.dist-info
# gcsfs
# gcsfs-2023.6.0.dist-info
# GDAL-3.6.4.dist-info
# gdown
# gdown-4.7.3.dist-info
# geemap
# geemap-0.32.0.dist-info
# gensim
# gensim-4.3.2.dist-info
# geocoder
# geocoder-1.38.1.dist-info
# geographiclib
# geographiclib-2.0.dist-info
# geopandas
# geopandas-0.13.2.dist-info
# geopy
# geopy-2.3.0.dist-info
# gin
# gin_config-0.5.0.dist-info
# glob2
# glob2-0.7.dist-info
# google
# google-2.0.3.dist-info
# google_ai_generativelanguage-0.4.0.dist-info
# googleapiclient
# google_api_core-2.11.1.dist-info
# google_api_core-2.11.1-py3.9-nspkg.pth
# google_api_python_client-2.84.0.dist-info
# googleapis_common_protos-1.63.0.dist-info
# google_auth-2.27.0.dist-info
# google_auth_httplib2-0.1.1.dist-info
# google_auth_httplib2.py
# google_auth_oauthlib
# google_auth_oauthlib-1.2.0.dist-info
# google_cloud_aiplatform-1.44.0.dist-info
# google_cloud_aiplatform-1.44.0-py3.9-nspkg.pth
# google_cloud_bigquery-3.12.0.dist-info
# google_cloud_bigquery-3.12.0-py3.9-nspkg.pth
# google_cloud_bigquery_connection-1.12.1.dist-info
# google_cloud_bigquery_connection-1.12.1-py3.9-nspkg.pth
# google_cloud_bigquery_storage-2.24.0.dist-info
# google_cloud_core-2.3.3.dist-info
# google_cloud_core-2.3.3-py3.9-nspkg.pth
# google_cloud_datastore-2.15.2.dist-info
# google_cloud_datastore-2.15.2-py3.9-nspkg.pth
# google_cloud_firestore-2.11.1.dist-info
# google_cloud_firestore-2.11.1-py3.9-nspkg.pth
# google_cloud_functions-1.13.3.dist-info
# google_cloud_functions-1.13.3-py3.9-nspkg.pth
# google_cloud_iam-2.14.3.dist-info
# google_cloud_language-2.13.3.dist-info
# google_cloud_resource_manager-1.12.3.dist-info
# google_cloud_storage-2.8.0.dist-info
# google_cloud_storage-2.8.0-py3.9-nspkg.pth
# google_cloud_translate-3.11.3.dist-info
# google_cloud_translate-3.11.3-py3.9-nspkg.pth
# google_colab-1.0.0.dist-info
# google_colab-1.0.0-py3.10-nspkg.pth
# google_crc32c
# google_crc32c-1.5.0.dist-info
# google_crc32c.libs
# google_drive_downloader
# googledrivedownloader-0.4.dist-info
# google_generativeai-0.3.2.dist-info
# google_generativeai-0.3.2-py3.11-nspkg.pth
# google_pasta-0.2.0.dist-info
# google_resumable_media-2.7.0.dist-info
# googlesearch
# graphviz
# graphviz-0.20.2.dist-info
# greenlet
# greenlet-3.0.3.dist-info
# grpc
# grpc_google_iam_v1-0.13.0.dist-info
# grpcio-1.62.1.dist-info
# grpcio_status-1.48.2.dist-info
# grpc_status
# gspread
# gspread-3.4.2.dist-info
# gspread_dataframe-3.3.1.dist-info
# gspread_dataframe.py
# gym
# gym-0.25.2.dist-info
# gym_notices
# gym_notices-0.0.8.dist-info
# h5netcdf
# h5netcdf-1.3.0.dist-info
# h5py
# h5py-3.9.0.dist-info
# h5py.libs
# helper
# holidays
# holidays-0.45.dist-info
# holoviews
# holoviews-1.17.1.dist-info
# html5lib
# html5lib-1.1.dist-info
# httpimport-1.3.1.dist-info
# httpimport.py
# httplib2
# httplib2-0.22.0.dist-info
# huggingface_hub
# huggingface_hub-0.20.3.dist-info
# humanize
# humanize-4.7.0.dist-info
# hyperopt
# hyperopt-0.2.7.dist-info
# ibis
# ibis_framework-8.0.0.dist-info
# idna
# idna-3.6.dist-info
# imageio
# imageio-2.31.6.dist-info
# imageio_ffmpeg
# imageio_ffmpeg-0.4.9.dist-info
# imagesize
# imagesize-1.4.1.dist-info
# imagesize.py
# imbalanced_learn-0.10.1.dist-info
# imblearn
# imgaug
# imgaug-0.4.0.dist-info
# importlib_metadata
# importlib_metadata-7.0.2.dist-info
# importlib_resources
# importlib_resources-6.3.2.dist-info
# imutils
# imutils-0.5.4.dist-info
# inflect
# inflect-7.0.0.dist-info
# iniconfig
# iniconfig-2.0.0.dist-info
# intel_openmp-2023.2.4.dist-info
# ipyevents
# ipyevents-2.0.2.dist-info
# ipyfilechooser
# ipyfilechooser-0.6.0.dist-info
# ipykernel
# ipykernel-5.5.6.dist-info
# ipykernel_launcher.py
# ipyleaflet
# ipyleaflet-0.18.2.dist-info
# IPython
# ipython-7.34.0.dist-info
# ipython_genutils
# ipython_genutils-0.2.0.dist-info
# ipython_sql-0.5.0.dist-info
# ipytree
# ipytree-0.2.2.dist-info
# ipywidgets
# ipywidgets-7.7.1.dist-info
# isympy.py
# itsdangerous
# itsdangerous-2.1.2.dist-info
# jax
# jax-0.4.23.dist-info
# jaxlib
# jaxlib-0.4.23+cuda12.cudnn89.dist-info
# jieba
# jieba-0.42.1.dist-info
# jinja2
# Jinja2-3.1.3.dist-info
# joblib
# joblib-1.3.2.dist-info
# jsonpickle
# jsonpickle-3.0.3.dist-info
# jsonschema
# jsonschema-4.19.2.dist-info
# jsonschema_specifications
# jsonschema_specifications-2023.12.1.dist-info
# jupyter_client
# jupyter_client-6.1.12.dist-info
# jupyter_console
# jupyter_console-6.1.0.dist-info
# jupyter_core
# jupyter_core-5.7.2.dist-info
# jupyterlab_plotly
# jupyterlab_pygments
# jupyterlab_pygments-0.3.0.dist-info
# jupyterlab_widgets
# jupyterlab_widgets-3.0.10.dist-info
# jupyter.py
# jupyter_server
# jupyter_server-1.24.0.dist-info
# kaggle
# kaggle-1.5.16.dist-info
# kagglehub
# kagglehub-0.2.0.dist-info
# kanren
# keras
# keras-2.15.0.dist-info
# kiwisolver
# kiwisolver-1.4.5.dist-info
# langcodes
# langcodes-3.3.0.dist-info
# lazy_loader
# lazy_loader-0.3.dist-info
# libclang-18.1.1.dist-info
# libfuturize
# libpasteurize
# librosa
# librosa-0.10.1.dist-info
# LICENSE
# lightgbm
# lightgbm-4.1.0.dist-info
# linkify_it
# linkify_it_py-2.0.3.dist-info
# llvmlite
# llvmlite-0.41.1.dist-info
# locket
# locket-1.0.0.dist-info
# logical_unification-0.4.6.dist-info
# lxml
# lxml-4.9.4.dist-info
# malloy
# malloy-2023.1067.dist-info
# markdown
# Markdown-3.6.dist-info
# markdown_it
# markdown_it_py-3.0.0.dist-info
# markupsafe
# MarkupSafe-2.1.5.dist-info
# matplotlib
# matplotlib-3.7.1.dist-info
# matplotlib-3.7.1-py3.10-nspkg.pth
# matplotlib_inline
# matplotlib_inline-0.1.6.dist-info
# matplotlib_venn
# matplotlib_venn-0.11.10.dist-info
# mdit_py_plugins
# mdit_py_plugins-0.4.0.dist-info
# mdurl
# mdurl-0.1.2.dist-info
# miniKanren-1.0.3.dist-info
# missingno
# missingno-0.5.2.dist-info
# mistune-0.8.4.dist-info
# mistune.py
# mizani
# mizani-0.9.3.dist-info
# mkl-2023.2.0.dist-info
# ml_dtypes
# ml_dtypes-0.2.0.dist-info
# mlxtend
# mlxtend-0.22.0.dist-info
# more_itertools
# more_itertools-10.1.0.dist-info
# moviepy
# moviepy-1.0.3.dist-info
# mpl_toolkits
# mpmath
# mpmath-1.3.0.dist-info
# msgpack
# msgpack-1.0.8.dist-info
# multidict
# multidict-6.0.5.dist-info
# multipledispatch
# multipledispatch-1.0.0.dist-info
# multitasking
# multitasking-0.0.11.dist-info
# murmurhash
# murmurhash-1.0.10.dist-info
# music21
# music21-9.1.0.dist-info
# natsort
# natsort-8.4.0.dist-info
# nbclassic
# nbclassic-1.0.0.dist-info
# nbclient
# nbclient-0.10.0.dist-info
# nbconvert
# nbconvert-6.5.4.dist-info
# nbformat
# nbformat-5.10.3.dist-info
# nest_asyncio-1.6.0.dist-info
# nest_asyncio.py
# networkx
# networkx-3.2.1.dist-info
# nibabel
# nibabel-4.0.2.dist-info
# nisext
# nltk
# nltk-3.8.1.dist-info
# notebook
# notebook-6.5.5.dist-info
# notebook_shim
# notebook_shim-0.2.4.dist-info
# numba
# numba-0.58.1.dist-info
# numbergen
# numexpr
# numexpr-2.9.0.dist-info
# numpy
# numpy-1.25.2.dist-info
# numpy.libs
# nvidia
# oauth2client
# oauth2client-4.1.3.dist-info
# oauthlib
# oauthlib-3.2.2.dist-info
# opencv_contrib_python-4.8.0.76.dist-info
# opencv_contrib_python.libs
# opencv_python-4.8.0.76.dist-info
# opencv_python_headless-4.9.0.80.dist-info
# opencv_python_headless.libs
# opencv_python.libs
# OpenGL
# openpyxl
# openpyxl-3.1.2.dist-info
# OpenSSL
# optax
# optax-0.2.1.dist-info
# opt_einsum
# opt_einsum-3.3.0.dist-info
# orbax
# orbax_checkpoint-0.4.4.dist-info
# osgeo
# osgeo_utils
# osqp
# osqp-0.6.2.post8.dist-info
# osqppurepy
# packaging
# packaging-24.0.dist-info
# pandas
# pandas-1.5.3.dist-info
# pandas_datareader
# pandas_datareader-0.10.0.dist-info
# pandas_gbq
# pandas_gbq-0.19.2.dist-info
# pandas-stubs
# pandas_stubs-1.5.3.230304.dist-info
# pandocfilters-1.5.1.dist-info
# pandocfilters.py
# panel
# panel-1.3.8.dist-info
# param
# param-2.0.2.dist-info
# parso
# parso-0.8.3.dist-info
# parsy
# parsy-2.1.dist-info
# partd
# partd-1.4.1.dist-info
# past
# pasta
# pathlib-1.0.1.dist-info
# pathlib.py
# patsy
# patsy-0.5.6.dist-info
# peewee-3.17.1.dist-info
# peewee.py
# pexpect
# pexpect-4.9.0.dist-info
# pickleshare-0.7.5.dist-info
# pickleshare.py
# PIL
# Pillow-9.4.0.dist-info
# Pillow.libs
# pip
# pip-23.1.2.dist-info
# piptools
# pip_tools-6.13.0.dist-info
# pkg_resources
# pkg_resources-stubs
# platformdirs
# platformdirs-4.2.0.dist-info
# playhouse
# plotly
# plotly-5.15.0.dist-info
# _plotly_future_
# _plotly_utils
# plotnine
# plotnine-0.12.4.dist-info
# pluggy
# pluggy-1.4.0.dist-info
# polars
# polars-0.20.2.dist-info
# pooch
# pooch-1.8.1.dist-info
# portpicker-1.5.2.dist-info
# portpicker.py
# prefetch_generator
# prefetch_generator-1.0.3.dist-info
# preshed
# preshed-3.0.9.dist-info
# prettytable
# prettytable-3.10.0.dist-info
# proglog
# proglog-0.1.10.dist-info
# progressbar
# progressbar2-4.2.0.dist-info
# prometheus_client
# prometheus_client-0.20.0.dist-info
# promise
# promise-2.3.dist-info
# prompt_toolkit
# prompt_toolkit-3.0.43.dist-info
# prophet
# prophet-1.1.5.dist-info
# prophet.libs
# proto
# protobuf-3.20.3.dist-info
# protobuf-3.20.3-py3.10-nspkg.pth
# proto_plus-1.23.0.dist-info
# psutil
# psutil-5.9.5.dist-info
# psycopg2
# psycopg2-2.9.9.dist-info
# ptyprocess
# ptyprocess-0.7.0.dist-info
# public
# pwiz.py
# py4j
# py4j-0.10.9.7.dist-info
# pyarrow
# pyarrow-14.0.2.dist-info
# pyarrow_hotfix
# pyarrow_hotfix-0.6.dist-info
# pyasn1
# pyasn1-0.5.1.dist-info
# pyasn1_modules
# pyasn1_modules-0.3.0.dist-info
# __pycache__
# pycocotools
# pycocotools-2.0.7.dist-info
# pycparser
# pycparser-2.21.dist-info
# py_cpuinfo-9.0.0.dist-info
# pydantic
# pydantic-2.6.4.dist-info
# pydantic_core
# pydantic_core-2.16.3.dist-info
# pydata_google_auth
# pydata_google_auth-1.8.2.dist-info
# pydot-1.4.2.dist-info
# pydot_ng
# pydot_ng-2.0.0.dist-info
# pydotplus
# pydotplus-2.0.2.dist-info
# pydot.py
# pydrive
# PyDrive-1.3.1.dist-info
# pydrive2
# PyDrive2-1.6.3.dist-info
# pyerfa-2.0.1.1.dist-info
# pygame
# pygame-2.5.2.dist-info
# pygame.libs
# pygments
# Pygments-2.16.1.dist-info
# pylab.py
# pymc
# pymc-5.10.4.dist-info
# pymystem3
# pymystem3-0.2.0.dist-info
# PyOpenGL-3.1.7.dist-info
# pyOpenSSL-24.1.0.dist-info
# pyparsing
# pyparsing-3.1.2.dist-info
# pyperclip
# pyperclip-1.8.2.dist-info
# pyproj
# pyproj-3.6.1.dist-info
# pyproject_hooks
# pyproject_hooks-1.0.0.dist-info
# pyproj.libs
# py.py
# pyshp-2.3.1.dist-info
# PySocks-1.7.1.dist-info
# pytensor
# pytensor-2.18.6.dist-info
# _pytest
# pytest
# pytest-7.4.4.dist-info
# python_apt-0.0.0.dist-info
# python_box-7.1.1.dist-info
# python_dateutil-2.8.2.dist-info
# python_louvain-0.16.dist-info
# python_slugify-8.0.4.dist-info
# python_utils
# python_utils-3.8.2.dist-info
# pytz
# pytz-2023.4.dist-info
# pytz-stubs
# pyviz_comms
# pyviz_comms-3.0.1.dist-info
# pywavelets-1.5.0.dist-info
# pywt
# pyximport
# PyYAML-6.0.1.dist-info
# pyzmq-23.2.1.dist-info
# pyzmq.libs
# qdldl-0.1.7.post0.dist-info
# qdldl.cpython-310-x86_64-linux-gnu.so
# qudida
# qudida-0.0.4.dist-info
# ratelim
# ratelim-0.1.6.dist-info
# README.md
# referencing
# referencing-0.34.0.dist-info
# regex
# regex-2023.12.25.dist-info
# requests
# requests-2.31.0.dist-info
# requests_oauthlib
# requests_oauthlib-1.4.0.dist-info
# requirements
# requirements_parser-0.5.0.dist-info
# rich
# rich-13.7.1.dist-info
# _rinterface_cffi_abi.py
# _rinterface_cffi_api.abi3.so
# rpds
# rpds_py-0.18.0.dist-info
# rpy2
# rpy2-3.4.2.dist-info
# rsa
# rsa-4.9.dist-info
# rust-toolchain.toml
# safetensors
# safetensors-0.4.2.dist-info
# scikit_image-0.19.3.dist-info
# scikit_image.libs
# scikit_learn-1.2.2.dist-info
# scikit_learn.libs
# scipy
# scipy-1.11.4.dist-info
# scipy.libs
# scooby
# scooby-0.9.2.dist-info
# scripts
# scs
# scs-3.2.4.post1.dist-info
# _scs_direct.cpython-310-x86_64-linux-gnu.so
# _scs_indirect.cpython-310-x86_64-linux-gnu.so
# scs.libs
# seaborn
# seaborn-0.13.1.dist-info
# send2trash
# Send2Trash-1.8.2.dist-info
# sentencepiece
# sentencepiece-0.1.99.dist-info
# setuptools
# setuptools-67.7.2.dist-info
# setuptools-stubs
# shapefile.py
# shapely
# shapely-2.0.3.dist-info
# shapely.libs
# six-1.16.0.dist-info
# six.py
# skimage
# sklearn
# sklearn_pandas
# sklearn_pandas-2.2.0.dist-info
# slugify
# smart_open
# smart_open-6.4.0.dist-info
# sniffio
# sniffio-1.3.1.dist-info
# snowballstemmer
# snowballstemmer-2.2.0.dist-info
# sockshandler.py
# socks.py
# sortedcontainers
# sortedcontainers-2.4.0.dist-info
# soundfile-0.12.1.dist-info
# _soundfile_data
# _soundfile.py
# soundfile.py
# soupsieve
# soupsieve-2.5.dist-info
# soxr
# soxr-0.3.7.dist-info
# spacy
# spacy-3.7.4.dist-info
# spacy_legacy
# spacy_legacy-3.0.12.dist-info
# spacy_loggers
# spacy_loggers-1.0.5.dist-info
# sphinx
# Sphinx-5.0.2.dist-info
# sphinxcontrib
# sphinxcontrib_applehelp-1.0.8.dist-info
# sphinxcontrib_devhelp-1.0.6.dist-info
# sphinxcontrib_htmlhelp-2.0.5.dist-info
# sphinxcontrib_jsmath-1.0.1.dist-info
# sphinxcontrib_jsmath-1.0.1-py3.7-nspkg.pth
# sphinxcontrib_qthelp-1.0.7.dist-info
# sphinxcontrib_serializinghtml-1.1.10.dist-info
# sql
# sqlalchemy
# SQLAlchemy-2.0.28.dist-info
# sqlglot
# sqlglot-20.11.0.dist-info
# sqlparse
# sqlparse-0.4.4.dist-info
# srsly
# srsly-2.4.8.dist-info
# stanio
# stanio-0.3.0.dist-info
# statsmodels
# statsmodels-0.14.1.dist-info
# sympy
# sympy-1.12.dist-info
# tables
# tables-3.8.0.dist-info
# tables.libs
# tabulate
# tabulate-0.9.0.dist-info
# tbb-2021.11.0.dist-info
# tblib
# tblib-3.0.0.dist-info
# tenacity
# tenacity-8.2.3.dist-info
# tensorboard
# tensorboard-2.15.2.dist-info
# tensorboard_data_server
# tensorboard_data_server-0.7.2.dist-info
# tensorflow
# tensorflow-2.15.0.dist-info
# tensorflow_datasets
# tensorflow_datasets-4.9.4.dist-info
# tensorflow_estimator
# tensorflow_estimator-2.15.0.dist-info
# tensorflow_gcs_config
# tensorflow_gcs_config-2.15.0.dist-info
# tensorflow_hub
# tensorflow_hub-0.16.1.dist-info
# tensorflow_io_gcs_filesystem
# tensorflow_io_gcs_filesystem-0.36.0.dist-info
# tensorflow_metadata
# tensorflow_metadata-1.14.0.dist-info
# tensorflow_probability
# tensorflow_probability-0.23.0.dist-info
# tensorstore
# tensorstore-0.1.45.dist-info
# termcolor
# termcolor-2.4.0.dist-info
# terminado
# terminado-0.18.1.dist-info
# textblob
# textblob-0.17.1.dist-info
# text_unidecode
# text_unidecode-1.3.dist-info
# tf_keras
# tf_keras-2.15.1.dist-info
# tf_slim
# tf_slim-1.1.0.dist-info
# thinc
# thinc-8.2.3.dist-info
# third_party
# threadpoolctl-3.3.0.dist-info
# threadpoolctl.py
# tifffile
# tifffile-2024.2.12.dist-info
# tinycss2
# tinycss2-1.2.1.dist-info
# tlz
# tokenizers
# tokenizers-0.15.2.dist-info
# toml
# toml-0.10.2.dist-info
# tomli
# tomli-2.0.1.dist-info
# toolz
# toolz-0.12.1.dist-info
# torch
# torch-2.2.1+cu121.dist-info
# torchaudio
# torchaudio-2.2.1+cu121.dist-info
# torchdata
# torchdata-0.7.1.dist-info
# torchgen
# torchsummary
# torchsummary-1.5.1.dist-info
# torchtext
# torchtext-0.17.1.dist-info
# torchvision
# torchvision-0.17.1+cu121.dist-info
# torchvision.libs
# torio
# tornado
# tornado-6.3.3.dist-info
# tqdm
# tqdm-4.66.2.dist-info
# traitlets
# traitlets-5.7.1.dist-info
# traittypes
# traittypes-0.2.1.dist-info
# transformers
# transformers-4.38.2.dist-info
# tree
# triton
# triton-2.2.0.dist-info
# tweepy
# tweepy-4.14.0.dist-info
# typer
# typer-0.9.0.dist-info
# types_pytz-2024.1.0.20240203.dist-info
# types_setuptools-69.2.0.20240317.dist-info
# typing_extensions-4.10.0.dist-info
# typing_extensions.py
# typings
# tzlocal
# tzlocal-5.2.dist-info
# uc_micro
# uc_micro_py-1.0.3.dist-info
# unification
# uritemplate
# uritemplate-4.1.1.dist-info
# urllib3
# urllib3-2.0.7.dist-info
# vega_datasets
# vega_datasets-0.9.0.dist-info
# vertexai
# vertex_ray
# wasabi
# wasabi-1.1.2.dist-info
# wcwidth
# wcwidth-0.2.13.dist-info
# weasel
# weasel-0.3.4.dist-info
# webcolors
# webcolors-1.13.dist-info
# webencodings
# webencodings-0.5.1.dist-info
# websocket
# websocket_client-1.7.0.dist-info
# werkzeug
# werkzeug-3.0.1.dist-info
# wheel
# wheel-0.43.0.dist-info
# widgetsnbextension
# widgetsnbextension-3.6.6.dist-info
# wordcloud
# wordcloud-1.9.3.dist-info
# wrapt
# wrapt-1.14.1.dist-info
# xarray
# xarray-2023.7.0.dist-info
# xarray_einstats
# xarray_einstats-0.7.0.dist-info
# xgboost
# xgboost-2.0.3.dist-info
# xgboost.libs
# xlrd
# xlrd-2.0.1.dist-info
# xyzservices
# xyzservices-2023.10.1.dist-info
# _yaml
# yaml
# yarl
# yarl-1.9.4.dist-info
# yellowbrick
# yellowbrick-1.5.dist-info
# yfinance
# yfinance-0.2.37.dist-info
# zict
# zict-3.0.0.dist-info
# zipp
# zipp-3.18.1.dist-info
# zmq

# %%
sys.path.append("/usr/local/lib/python3.10/site-packages")
# !conda config --add channels conda-forge

# %%
# !conda create --name musemotion_meta -c conda-forge numpy pandas matplotlib scikit-learn wandb pytorch torchvision torchaudio pytorch-cuda=12.1 -c pytorch -c nvidia
# Out:
# Streaming output truncated to the last 5000 lines.
#     libxkbcommon-1.7.0         |       h662e7e4_0         580 KB  conda-forge
#     libxml2-2.12.6             |       h232c23b_1         689 KB  conda-forge
#     libzlib-1.2.13             |       hd590300_5          60 KB  conda-forge
#     llvm-openmp-18.1.2         |       h4dfa4b3_0        57.6 MB  conda-forge
#     lz4-c-1.9.4                |       hcb278e6_0         140 KB  conda-forge
#     markupsafe-2.1.5           |  py311h459d7ec_0          27 KB  conda-forge
#     matplotlib-3.8.3           |  py311h38be061_0           8 KB  conda-forge
#     matplotlib-base-3.8.3      |  py311h54ef318_0         7.6 MB  conda-forge
#     mkl-2023.2.0               |   h84fe81f_50496       156.8 MB  conda-forge
#     mpc-1.3.1                  |       hfe3b2da_0         114 KB  conda-forge
#     mpfr-4.2.1                 |       h9458935_0         626 KB  conda-forge
#     mpg123-1.32.4              |       h59595ed_0         480 KB  conda-forge
#     mpmath-1.3.0               |     pyhd8ed1ab_0         428 KB  conda-forge
#     munkres-1.1.4              |     pyh9f0ad1d_0          12 KB  conda-forge
#     mysql-common-8.3.0         |       hf1915f5_4         766 KB  conda-forge
#     mysql-libs-8.3.0           |       hca2cd23_4         1.5 MB  conda-forge
#     ncurses-6.4.20240210       |       h59595ed_0         875 KB  conda-forge
#     networkx-3.2.1             |     pyhd8ed1ab_0         1.1 MB  conda-forge
#     nspr-4.35                  |       h27087fc_0         222 KB  conda-forge
#     nss-3.98                   |       h1d7d5a4_0         1.9 MB  conda-forge
#     numpy-1.26.4               |  py311h64a7726_0         7.7 MB  conda-forge
#     ocl-icd-2.3.2              |       hd590300_1         133 KB  conda-forge
#     openjpeg-2.5.2             |       h488ebb8_0         334 KB  conda-forge
#     openssl-3.2.1              |       hd590300_1         2.7 MB  conda-forge
#     packaging-24.0             |     pyhd8ed1ab_0          49 KB  conda-forge
#     pandas-2.2.1               |  py311h320fe9a_0        15.0 MB  conda-forge
#     pathtools-0.1.2            |             py_1           8 KB  conda-forge
#     pcre2-10.43                |       hcad00b1_0         929 KB  conda-forge
#     pillow-10.2.0              |  py311ha6c5da5_0        39.7 MB  conda-forge
#     pip-24.0                   |     pyhd8ed1ab_0         1.3 MB  conda-forge
#     pixman-0.43.2              |       h59595ed_0         378 KB  conda-forge
#     ply-3.11                   |             py_1          44 KB  conda-forge
#     protobuf-4.25.1            |  py311h46cbc50_0         390 KB  conda-forge
#     psutil-5.9.8               |  py311h459d7ec_0         494 KB  conda-forge
#     pthread-stubs-0.4          |    h36c2ea0_1001           5 KB  conda-forge
#     pulseaudio-client-17.0     |       hb77b528_0         740 KB  conda-forge
#     pyparsing-3.1.2            |     pyhd8ed1ab_0          87 KB  conda-forge
#     pyqt-5.15.9                |  py311hf0fb5b6_5         5.1 MB  conda-forge
#     pyqt5-sip-12.12.2          |  py311hb755f60_5          83 KB  conda-forge
#     pysocks-1.7.1              |     pyha2e5f31_6          19 KB  conda-forge
#     python-3.11.8              |hab00c5b_0_cpython        29.3 MB  conda-forge
#     python-dateutil-2.9.0      |     pyhd8ed1ab_0         218 KB  conda-forge
#     python-tzdata-2024.1       |     pyhd8ed1ab_0         141 KB  conda-forge
#     python_abi-3.11            |          4_cp311           6 KB  conda-forge
#     pytorch-2.1.2              |cpu_mkl_py311hc5c8824_103        27.8 MB  conda-forge
#     pytorch-cuda-12.1          |       ha16c6d3_5           3 KB  pytorch
#     pytorch-mutex-1.0          |             cuda           3 KB  pytorch
#     pytz-2024.1                |     pyhd8ed1ab_0         184 KB  conda-forge
#     pyyaml-6.0.1               |  py311h459d7ec_1         196 KB  conda-forge
#     qt-main-5.15.8             |      h112747c_20        58.0 MB  conda-forge
#     readline-8.2               |       h8228510_1         275 KB  conda-forge
#     requests-2.31.0            |     pyhd8ed1ab_0          55 KB  conda-forge
#     scikit-learn-1.4.1.post1   |  py311hc009520_0         9.9 MB  conda-forge
#     scipy-1.12.0               |  py311h64a7726_2        16.5 MB  conda-forge
#     sentry-sdk-1.43.0          |     pyhd8ed1ab_0         168 KB  conda-forge
#     setproctitle-1.3.3         |  py311h459d7ec_0          20 KB  conda-forge
#     setuptools-69.2.0          |     pyhd8ed1ab_0         460 KB  conda-forge
#     sip-6.7.12                 |  py311hb755f60_0         571 KB  conda-forge
#     six-1.16.0                 |     pyh6c4a22f_0          14 KB  conda-forge
#     sleef-3.5.1                |       h9b69904_2         1.5 MB  conda-forge
#     smmap-5.0.0                |     pyhd8ed1ab_0          22 KB  conda-forge
#     sympy-1.12                 | pypyh9d50eac_103         4.1 MB  conda-forge
#     tbb-2021.11.0              |       h00ab1b0_1         191 KB  conda-forge
#     threadpoolctl-3.4.0        |     pyhc1e730c_0          22 KB  conda-forge
#     tk-8.6.13                  |noxft_h4845f30_101         3.2 MB  conda-forge
#     toml-0.10.2                |     pyhd8ed1ab_0          18 KB  conda-forge
#     tomli-2.0.1                |     pyhd8ed1ab_0          16 KB  conda-forge
#     torchaudio-2.1.2           |      py311_cu121         6.2 MB  pytorch
#     torchvision-0.16.1         |cpu_py311h5d47fc7_3        10.0 MB  conda-forge
#     tornado-6.4                |  py311h459d7ec_0         833 KB  conda-forge
#     typing_extensions-4.10.0   |     pyha770c72_0          36 KB  conda-forge
#     tzdata-2024a               |       h0c530f3_0         117 KB  conda-forge
#     urllib3-2.2.1              |     pyhd8ed1ab_0          92 KB  conda-forge
#     wandb-0.16.3               |     pyhd8ed1ab_0         1.4 MB  conda-forge
#     wheel-0.43.0               |     pyhd8ed1ab_0          57 KB  conda-forge
#     xcb-util-0.4.0             |       hd590300_1          19 KB  conda-forge
#     xcb-util-image-0.4.0       |       h8ee46fc_1          24 KB  conda-forge
#     xcb-util-keysyms-0.4.0     |       h8ee46fc_1          14 KB  conda-forge
#     xcb-util-renderutil-0.3.9  |       hd590300_1          17 KB  conda-forge
#     xcb-util-wm-0.4.1          |       h8ee46fc_1          51 KB  conda-forge
#     xkeyboard-config-2.41      |       hd590300_0         877 KB  conda-forge
#     xorg-kbproto-1.0.7         |    h7f98852_1002          27 KB  conda-forge
#     xorg-libice-1.1.1          |       hd590300_0          57 KB  conda-forge
#     xorg-libsm-1.2.4           |       h7391055_0          27 KB  conda-forge
#     xorg-libx11-1.8.7          |       h8ee46fc_0         809 KB  conda-forge
#     xorg-libxau-1.0.11         |       hd590300_0          14 KB  conda-forge
#     xorg-libxdmcp-1.1.3        |       h7f98852_0          19 KB  conda-forge
#     xorg-libxext-1.3.4         |       h0b41bf4_2          49 KB  conda-forge
#     xorg-libxrender-0.9.11     |       hd590300_0          37 KB  conda-forge
#     xorg-renderproto-0.11.1    |    h7f98852_1002           9 KB  conda-forge
#     xorg-xextproto-7.3.0       |    h0b41bf4_1003          30 KB  conda-forge
#     xorg-xf86vidmodeproto-2.3.1|    h7f98852_1002          23 KB  conda-forge
#     xorg-xproto-7.0.31         |    h7f98852_1007          73 KB  conda-forge
#     xz-5.2.6                   |       h166bdaf_0         409 KB  conda-forge
#     yaml-0.2.5                 |       h7f98852_2          87 KB  conda-forge
#     zlib-1.2.13                |       hd590300_5          91 KB  conda-forge
#     zstd-1.5.5                 |       hfc55251_0         532 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        1.57 GB
#
# The following NEW packages will be INSTALLED:
#
#   _libgcc_mutex      conda-forge/linux-64::_libgcc_mutex-0.1-conda_forge
#   _openmp_mutex      conda-forge/linux-64::_openmp_mutex-4.5-2_kmp_llvm
#   alsa-lib           conda-forge/linux-64::alsa-lib-1.2.11-hd590300_1
#   appdirs            conda-forge/noarch::appdirs-1.4.4-pyh9f0ad1d_0
#   attr               conda-forge/linux-64::attr-2.5.1-h166bdaf_1
#   brotli             conda-forge/linux-64::brotli-1.1.0-hd590300_1
#   brotli-bin         conda-forge/linux-64::brotli-bin-1.1.0-hd590300_1
#   brotli-python      conda-forge/linux-64::brotli-python-1.1.0-py311hb755f60_1
#   bzip2              conda-forge/linux-64::bzip2-1.0.8-hd590300_5
#   ca-certificates    conda-forge/linux-64::ca-certificates-2024.2.2-hbcca054_0
#   cairo              conda-forge/linux-64::cairo-1.18.0-h3faef2a_0
#   certifi            conda-forge/noarch::certifi-2024.2.2-pyhd8ed1ab_0
#   charset-normalizer conda-forge/noarch::charset-normalizer-3.3.2-pyhd8ed1ab_0
#   click              conda-forge/noarch::click-8.1.7-unix_pyh707e725_0
#   contourpy          conda-forge/linux-64::contourpy-1.2.0-py311h9547e67_0
#   cuda-cudart        conda-forge/linux-64::cuda-cudart-12.1.105-hd3aeb46_0
#   cuda-cudart_linux~ conda-forge/noarch::cuda-cudart_linux-64-12.1.105-h59595ed_0
#   cuda-cupti         conda-forge/linux-64::cuda-cupti-12.1.105-h59595ed_0
#   cuda-libraries     nvidia/linux-64::cuda-libraries-12.1.0-0
#   cuda-nvrtc         conda-forge/linux-64::cuda-nvrtc-12.1.105-hd3aeb46_0
#   cuda-nvtx          conda-forge/linux-64::cuda-nvtx-12.1.105-h59595ed_0
#   cuda-opencl        conda-forge/linux-64::cuda-opencl-12.1.105-h59595ed_0
#   cuda-runtime       nvidia/linux-64::cuda-runtime-12.1.0-0
#   cuda-version       conda-forge/noarch::cuda-version-12.1-h1d6eff3_3
#   cycler             conda-forge/noarch::cycler-0.12.1-pyhd8ed1ab_0
#   dbus               conda-forge/linux-64::dbus-1.13.6-h5008d03_3
#   docker-pycreds     conda-forge/noarch::docker-pycreds-0.4.0-py_0
#   expat              conda-forge/linux-64::expat-2.6.2-h59595ed_0
#   filelock           conda-forge/noarch::filelock-3.13.3-pyhd8ed1ab_0
#   font-ttf-dejavu-s~ conda-forge/noarch::font-ttf-dejavu-sans-mono-2.37-hab24e00_0
#   font-ttf-inconsol~ conda-forge/noarch::font-ttf-inconsolata-3.000-h77eed37_0
#   font-ttf-source-c~ conda-forge/noarch::font-ttf-source-code-pro-2.038-h77eed37_0
#   font-ttf-ubuntu    conda-forge/noarch::font-ttf-ubuntu-0.83-h77eed37_1
#   fontconfig         conda-forge/linux-64::fontconfig-2.14.2-h14ed4e7_0
#   fonts-conda-ecosy~ conda-forge/noarch::fonts-conda-ecosystem-1-0
#   fonts-conda-forge  conda-forge/noarch::fonts-conda-forge-1-0
#   fonttools          conda-forge/linux-64::fonttools-4.50.0-py311h459d7ec_0
#   freetype           conda-forge/linux-64::freetype-2.12.1-h267a509_2
#   fsspec             conda-forge/noarch::fsspec-2024.3.1-pyhca7485f_0
#   gettext            conda-forge/linux-64::gettext-0.21.1-h27087fc_0
#   gitdb              conda-forge/noarch::gitdb-4.0.11-pyhd8ed1ab_0
#   gitpython          conda-forge/noarch::gitpython-3.1.42-pyhd8ed1ab_0
#   glib               conda-forge/linux-64::glib-2.80.0-hf2295e7_1
#   glib-tools         conda-forge/linux-64::glib-tools-2.80.0-hde27a5a_1
#   gmp                conda-forge/linux-64::gmp-6.3.0-h59595ed_1
#   gmpy2              conda-forge/linux-64::gmpy2-2.1.2-py311h6a5fa03_1
#   graphite2          conda-forge/linux-64::graphite2-1.3.13-h58526e2_1001
#   gst-plugins-base   conda-forge/linux-64::gst-plugins-base-1.22.9-hfa15dee_1
#   gstreamer          conda-forge/linux-64::gstreamer-1.22.9-h98fc4e7_1
#   harfbuzz           conda-forge/linux-64::harfbuzz-8.3.0-h3d44ed6_0
#   icu                conda-forge/linux-64::icu-73.2-h59595ed_0
#   idna               conda-forge/noarch::idna-3.6-pyhd8ed1ab_0
#   jinja2             conda-forge/noarch::jinja2-3.1.3-pyhd8ed1ab_0
#   joblib             conda-forge/noarch::joblib-1.3.2-pyhd8ed1ab_0
#   keyutils           conda-forge/linux-64::keyutils-1.6.1-h166bdaf_0
#   kiwisolver         conda-forge/linux-64::kiwisolver-1.4.5-py311h9547e67_1
#   krb5               conda-forge/linux-64::krb5-1.21.2-h659d440_0
#   lame               conda-forge/linux-64::lame-3.100-h166bdaf_1003
#   lcms2              conda-forge/linux-64::lcms2-2.16-hb7c19ff_0
#   ld_impl_linux-64   conda-forge/linux-64::ld_impl_linux-64-2.40-h41732ed_0
#   lerc               conda-forge/linux-64::lerc-4.0.0-h27087fc_0
#   libabseil          conda-forge/linux-64::libabseil-20230802.1-cxx17_h59595ed_0
#   libblas            conda-forge/linux-64::libblas-3.9.0-21_linux64_openblas
#   libbrotlicommon    conda-forge/linux-64::libbrotlicommon-1.1.0-hd590300_1
#   libbrotlidec       conda-forge/linux-64::libbrotlidec-1.1.0-hd590300_1
#   libbrotlienc       conda-forge/linux-64::libbrotlienc-1.1.0-hd590300_1
#   libcap             conda-forge/linux-64::libcap-2.69-h0f662aa_0
#   libcblas           conda-forge/linux-64::libcblas-3.9.0-21_linux64_openblas
#   libclang-cpp15     conda-forge/linux-64::libclang-cpp15-15.0.7-default_h127d8a8_5
#   libclang13         conda-forge/linux-64::libclang13-18.1.2-default_h5d6823c_1
#   libcublas          nvidia/linux-64::libcublas-12.1.0.26-0
#   libcufft           nvidia/linux-64::libcufft-11.0.2.4-0
#   libcufile          conda-forge/linux-64::libcufile-1.6.1.9-hd3aeb46_0
#   libcups            conda-forge/linux-64::libcups-2.3.3-h4637d8d_4
#   libcurand          conda-forge/linux-64::libcurand-10.3.2.106-hd3aeb46_0
#   libcusolver        nvidia/linux-64::libcusolver-11.4.4.55-0
#   libcusparse        nvidia/linux-64::libcusparse-12.0.2.55-0
#   libdeflate         conda-forge/linux-64::libdeflate-1.20-hd590300_0
#   libedit            conda-forge/linux-64::libedit-3.1.20191231-he28a2e2_2
#   libevent           conda-forge/linux-64::libevent-2.1.12-hf998b51_1
#   libexpat           conda-forge/linux-64::libexpat-2.6.2-h59595ed_0
#   libffi             conda-forge/linux-64::libffi-3.4.2-h7f98852_5
#   libflac            conda-forge/linux-64::libflac-1.4.3-h59595ed_0
#   libgcc-ng          conda-forge/linux-64::libgcc-ng-13.2.0-h807b86a_5
#   libgcrypt          conda-forge/linux-64::libgcrypt-1.10.3-hd590300_0
#   libgfortran-ng     conda-forge/linux-64::libgfortran-ng-13.2.0-h69a702a_5
#   libgfortran5       conda-forge/linux-64::libgfortran5-13.2.0-ha4646dd_5
#   libglib            conda-forge/linux-64::libglib-2.80.0-hf2295e7_1
#   libgpg-error       conda-forge/linux-64::libgpg-error-1.48-h71f35ed_0
#   libhwloc           conda-forge/linux-64::libhwloc-2.9.3-default_h554bfaf_1009
#   libiconv           conda-forge/linux-64::libiconv-1.17-hd590300_2
#   libjpeg-turbo      conda-forge/linux-64::libjpeg-turbo-3.0.0-hd590300_1
#   liblapack          conda-forge/linux-64::liblapack-3.9.0-21_linux64_openblas
#   libllvm15          conda-forge/linux-64::libllvm15-15.0.7-hb3ce162_4
#   libllvm18          conda-forge/linux-64::libllvm18-18.1.2-h2448989_0
#   libnpp             nvidia/linux-64::libnpp-12.0.2.50-0
#   libnsl             conda-forge/linux-64::libnsl-2.0.1-hd590300_0
#   libnvjitlink       conda-forge/linux-64::libnvjitlink-12.1.105-hd3aeb46_0
#   libnvjpeg          nvidia/linux-64::libnvjpeg-12.1.1.14-0
#   libogg             conda-forge/linux-64::libogg-1.3.4-h7f98852_1
#   libopenblas        conda-forge/linux-64::libopenblas-0.3.26-pthreads_h413a1c8_0
#   libopus            conda-forge/linux-64::libopus-1.3.1-h7f98852_1
#   libpng             conda-forge/linux-64::libpng-1.6.43-h2797004_0
#   libpq              conda-forge/linux-64::libpq-16.2-h33b98f1_1
#   libprotobuf        conda-forge/linux-64::libprotobuf-4.25.1-hf27288f_2
#   libsndfile         conda-forge/linux-64::libsndfile-1.2.2-hc60ed4a_1
#   libsqlite          conda-forge/linux-64::libsqlite-3.45.2-h2797004_0
#   libstdcxx-ng       conda-forge/linux-64::libstdcxx-ng-13.2.0-h7e041cc_5
#   libsystemd0        conda-forge/linux-64::libsystemd0-255-h3516f8a_1
#   libtiff            conda-forge/linux-64::libtiff-4.6.0-h1dd3fc0_3
#   libtorch           conda-forge/linux-64::libtorch-2.1.2-cpu_mkl_hcefb67d_103
#   libuuid            conda-forge/linux-64::libuuid-2.38.1-h0b41bf4_0
#   libuv              conda-forge/linux-64::libuv-1.48.0-hd590300_0
#   libvorbis          conda-forge/linux-64::libvorbis-1.3.7-h9c3ff4c_0
#   libwebp-base       conda-forge/linux-64::libwebp-base-1.3.2-hd590300_0
#   libxcb             conda-forge/linux-64::libxcb-1.15-h0b41bf4_0
#   libxcrypt          conda-forge/linux-64::libxcrypt-4.4.36-hd590300_1
#   libxkbcommon       conda-forge/linux-64::libxkbcommon-1.7.0-h662e7e4_0
#   libxml2            conda-forge/linux-64::libxml2-2.12.6-h232c23b_1
#   libzlib            conda-forge/linux-64::libzlib-1.2.13-hd590300_5
#   llvm-openmp        conda-forge/linux-64::llvm-openmp-18.1.2-h4dfa4b3_0
#   lz4-c              conda-forge/linux-64::lz4-c-1.9.4-hcb278e6_0
#   markupsafe         conda-forge/linux-64::markupsafe-2.1.5-py311h459d7ec_0
#   matplotlib         conda-forge/linux-64::matplotlib-3.8.3-py311h38be061_0
#   matplotlib-base    conda-forge/linux-64::matplotlib-base-3.8.3-py311h54ef318_0
#   mkl                conda-forge/linux-64::mkl-2023.2.0-h84fe81f_50496
#   mpc                conda-forge/linux-64::mpc-1.3.1-hfe3b2da_0
#   mpfr               conda-forge/linux-64::mpfr-4.2.1-h9458935_0
#   mpg123             conda-forge/linux-64::mpg123-1.32.4-h59595ed_0
#   mpmath             conda-forge/noarch::mpmath-1.3.0-pyhd8ed1ab_0
#   munkres            conda-forge/noarch::munkres-1.1.4-pyh9f0ad1d_0
#   mysql-common       conda-forge/linux-64::mysql-common-8.3.0-hf1915f5_4
#   mysql-libs         conda-forge/linux-64::mysql-libs-8.3.0-hca2cd23_4
#   ncurses            conda-forge/linux-64::ncurses-6.4.20240210-h59595ed_0
#   networkx           conda-forge/noarch::networkx-3.2.1-pyhd8ed1ab_0
#   nspr               conda-forge/linux-64::nspr-4.35-h27087fc_0
#   nss                conda-forge/linux-64::nss-3.98-h1d7d5a4_0
#   numpy              conda-forge/linux-64::numpy-1.26.4-py311h64a7726_0
#   ocl-icd            conda-forge/linux-64::ocl-icd-2.3.2-hd590300_1
#   openjpeg           conda-forge/linux-64::openjpeg-2.5.2-h488ebb8_0
#   openssl            conda-forge/linux-64::openssl-3.2.1-hd590300_1
#   packaging          conda-forge/noarch::packaging-24.0-pyhd8ed1ab_0
#   pandas             conda-forge/linux-64::pandas-2.2.1-py311h320fe9a_0
#   pathtools          conda-forge/noarch::pathtools-0.1.2-py_1
#   pcre2              conda-forge/linux-64::pcre2-10.43-hcad00b1_0
#   pillow             conda-forge/linux-64::pillow-10.2.0-py311ha6c5da5_0
#   pip                conda-forge/noarch::pip-24.0-pyhd8ed1ab_0
#   pixman             conda-forge/linux-64::pixman-0.43.2-h59595ed_0
#   ply                conda-forge/noarch::ply-3.11-py_1
#   protobuf           conda-forge/linux-64::protobuf-4.25.1-py311h46cbc50_0
#   psutil             conda-forge/linux-64::psutil-5.9.8-py311h459d7ec_0
#   pthread-stubs      conda-forge/linux-64::pthread-stubs-0.4-h36c2ea0_1001
#   pulseaudio-client  conda-forge/linux-64::pulseaudio-client-17.0-hb77b528_0
#   pyparsing          conda-forge/noarch::pyparsing-3.1.2-pyhd8ed1ab_0
#   pyqt               conda-forge/linux-64::pyqt-5.15.9-py311hf0fb5b6_5
#   pyqt5-sip          conda-forge/linux-64::pyqt5-sip-12.12.2-py311hb755f60_5
#   pysocks            conda-forge/noarch::pysocks-1.7.1-pyha2e5f31_6
#   python             conda-forge/linux-64::python-3.11.8-hab00c5b_0_cpython
#   python-dateutil    conda-forge/noarch::python-dateutil-2.9.0-pyhd8ed1ab_0
#   python-tzdata      conda-forge/noarch::python-tzdata-2024.1-pyhd8ed1ab_0
#   python_abi         conda-forge/linux-64::python_abi-3.11-4_cp311
#   pytorch            conda-forge/linux-64::pytorch-2.1.2-cpu_mkl_py311hc5c8824_103
#   pytorch-cuda       pytorch/linux-64::pytorch-cuda-12.1-ha16c6d3_5
#   pytorch-mutex      pytorch/noarch::pytorch-mutex-1.0-cuda
#   pytz               conda-forge/noarch::pytz-2024.1-pyhd8ed1ab_0
#   pyyaml             conda-forge/linux-64::pyyaml-6.0.1-py311h459d7ec_1
#   qt-main            conda-forge/linux-64::qt-main-5.15.8-h112747c_20
#   readline           conda-forge/linux-64::readline-8.2-h8228510_1
#   requests           conda-forge/noarch::requests-2.31.0-pyhd8ed1ab_0
#   scikit-learn       conda-forge/linux-64::scikit-learn-1.4.1.post1-py311hc009520_0
#   scipy              conda-forge/linux-64::scipy-1.12.0-py311h64a7726_2
#   sentry-sdk         conda-forge/noarch::sentry-sdk-1.43.0-pyhd8ed1ab_0
#   setproctitle       conda-forge/linux-64::setproctitle-1.3.3-py311h459d7ec_0
#   setuptools         conda-forge/noarch::setuptools-69.2.0-pyhd8ed1ab_0
#   sip                conda-forge/linux-64::sip-6.7.12-py311hb755f60_0
#   six                conda-forge/noarch::six-1.16.0-pyh6c4a22f_0
#   sleef              conda-forge/linux-64::sleef-3.5.1-h9b69904_2
#   smmap              conda-forge/noarch::smmap-5.0.0-pyhd8ed1ab_0
#   sympy              conda-forge/noarch::sympy-1.12-pypyh9d50eac_103
#   tbb                conda-forge/linux-64::tbb-2021.11.0-h00ab1b0_1
#   threadpoolctl      conda-forge/noarch::threadpoolctl-3.4.0-pyhc1e730c_0
#   tk                 conda-forge/linux-64::tk-8.6.13-noxft_h4845f30_101
#   toml               conda-forge/noarch::toml-0.10.2-pyhd8ed1ab_0
#   tomli              conda-forge/noarch::tomli-2.0.1-pyhd8ed1ab_0
#   torchaudio         pytorch/linux-64::torchaudio-2.1.2-py311_cu121
#   torchvision        conda-forge/linux-64::torchvision-0.16.1-cpu_py311h5d47fc7_3
#   tornado            conda-forge/linux-64::tornado-6.4-py311h459d7ec_0
#   typing_extensions  conda-forge/noarch::typing_extensions-4.10.0-pyha770c72_0
#   tzdata             conda-forge/noarch::tzdata-2024a-h0c530f3_0
#   urllib3            conda-forge/noarch::urllib3-2.2.1-pyhd8ed1ab_0
#   wandb              conda-forge/noarch::wandb-0.16.3-pyhd8ed1ab_0
#   wheel              conda-forge/noarch::wheel-0.43.0-pyhd8ed1ab_0
#   xcb-util           conda-forge/linux-64::xcb-util-0.4.0-hd590300_1
#   xcb-util-image     conda-forge/linux-64::xcb-util-image-0.4.0-h8ee46fc_1
#   xcb-util-keysyms   conda-forge/linux-64::xcb-util-keysyms-0.4.0-h8ee46fc_1
#   xcb-util-renderut~ conda-forge/linux-64::xcb-util-renderutil-0.3.9-hd590300_1
#   xcb-util-wm        conda-forge/linux-64::xcb-util-wm-0.4.1-h8ee46fc_1
#   xkeyboard-config   conda-forge/linux-64::xkeyboard-config-2.41-hd590300_0
#   xorg-kbproto       conda-forge/linux-64::xorg-kbproto-1.0.7-h7f98852_1002
#   xorg-libice        conda-forge/linux-64::xorg-libice-1.1.1-hd590300_0
#   xorg-libsm         conda-forge/linux-64::xorg-libsm-1.2.4-h7391055_0
#   xorg-libx11        conda-forge/linux-64::xorg-libx11-1.8.7-h8ee46fc_0
#   xorg-libxau        conda-forge/linux-64::xorg-libxau-1.0.11-hd590300_0
#   xorg-libxdmcp      conda-forge/linux-64::xorg-libxdmcp-1.1.3-h7f98852_0
#   xorg-libxext       conda-forge/linux-64::xorg-libxext-1.3.4-h0b41bf4_2
#   xorg-libxrender    conda-forge/linux-64::xorg-libxrender-0.9.11-hd590300_0
#   xorg-renderproto   conda-forge/linux-64::xorg-renderproto-0.11.1-h7f98852_1002
#   xorg-xextproto     conda-forge/linux-64::xorg-xextproto-7.3.0-h0b41bf4_1003
#   xorg-xf86vidmodep~ conda-forge/linux-64::xorg-xf86vidmodeproto-2.3.1-h7f98852_1002
#   xorg-xproto        conda-forge/linux-64::xorg-xproto-7.0.31-h7f98852_1007
#   xz                 conda-forge/linux-64::xz-5.2.6-h166bdaf_0
#   yaml               conda-forge/linux-64::yaml-0.2.5-h7f98852_2
#   zlib               conda-forge/linux-64::zlib-1.2.13-hd590300_5
#   zstd               conda-forge/linux-64::zstd-1.5.5-hfc55251_0
#
#
# Proceed ([y]/n)?
#
#
# Downloading and Extracting Packages:
# libcublas-12.1.0.26  | 329.0 MB  | :   0% 0/1 [00:00<?, ?it/s]
# libcusparse-12.0.2.5 | 163.0 MB  | :   0% 0/1 [00:00<?, ?it/s]
#
# mkl-2023.2.0         | 156.8 MB  | :   0% 0/1 [00:00<?, ?it/s]
#
#
# libnpp-12.0.2.50     | 139.8 MB  | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
# libcufft-11.0.2.4    | 102.9 MB  | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
# libcusolver-11.4.4.5 | 98.3 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
# qt-main-5.15.8       | 58.0 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
# llvm-openmp-18.1.2   | 57.6 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
# libtorch-2.1.2       | 45.2 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
# libcurand-10.3.2.106 | 39.8 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
# pillow-10.2.0        | 39.7 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
# libllvm18-18.1.2     | 36.6 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
# libllvm15-15.0.7     | 31.8 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.11.8        | 29.3 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.2        | 27.8 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.1.105  | 17.1 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 16.5 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libclang-cpp15-15.0. | 16.4 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.2.1         | 15.0 MB   | :   0% 0/1 [00:00<?, ?it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
# mkl-2023.2.0         | 156.8 MB  | :   0% 9.963948980324163e-05/1 [00:00<1:08:10, 4091.40s/it]
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :   0% 4.7496622446298464e-05/1 [00:00<2:39:01, 9541.57s/it]
#
#
#
# libcufft-11.0.2.4    | 102.9 MB  | :   0% 0.0001518791001574902/1 [00:00<48:26, 2906.85s/it]
# libcusparse-12.0.2.5 | 163.0 MB  | :   0% 9.588357486739811e-05/1 [00:00<1:24:12, 5052.74s/it]
#
# mkl-2023.2.0         | 156.8 MB  | :   3% 0.02750049918569469/1 [00:00<00:13, 14.03s/it]
#
#
# libnpp-12.0.2.50     | 139.8 MB  | :   2% 0.020794650594040023/1 [00:00<00:19, 19.58s/it]
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :   1% 0.009119351509689306/1 [00:00<00:45, 46.35s/it]
# libcusparse-12.0.2.5 | 163.0 MB  | :   1% 0.012368981157894357/1 [00:00<00:35, 35.69s/it]
#
# mkl-2023.2.0         | 156.8 MB  | :   5% 0.05201181367729213/1 [00:00<00:08,  8.53s/it]
#
#
#
# libcufft-11.0.2.4    | 102.9 MB  | :   6% 0.062118551964413495/1 [00:00<00:06,  7.20s/it]
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :   2% 0.019901084804999056/1 [00:00<00:22, 23.10s/it]
# libcusparse-12.0.2.5 | 163.0 MB  | :   3% 0.033751018353324135/1 [00:00<00:13, 14.17s/it]
#
# mkl-2023.2.0         | 156.8 MB  | :   8% 0.07602493071987336/1 [00:00<00:06,  6.76s/it]
#
#
#
# libcufft-11.0.2.4    | 102.9 MB  | :   9% 0.0883936362916593/1 [00:00<00:05,  5.80s/it]
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :   3% 0.028972939692242062/1 [00:00<00:18, 18.61s/it]
# libcusparse-12.0.2.5 | 163.0 MB  | :   6% 0.05695484347123448/1 [00:00<00:08,  9.36s/it]
#
# mkl-2023.2.0         | 156.8 MB  | :  10% 0.09914129235422542/1 [00:00<00:05,  5.86s/it]
#
#
#
# libcufft-11.0.2.4    | 102.9 MB  | :  11% 0.11360556691780267/1 [00:00<00:04,  5.19s/it]
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :   4% 0.038519760803948054/1 [00:00<00:14, 15.54s/it]
# libcusparse-12.0.2.5 | 163.0 MB  | :   8% 0.07833688066666426/1 [00:00<00:06,  7.56s/it]
#
# mkl-2023.2.0         | 156.8 MB  | :  12% 0.12056378266192237/1 [00:00<00:05,  5.71s/it]
#
#
#
# libcufft-11.0.2.4    | 102.9 MB  | :  15% 0.14823400175371043/1 [00:00<00:03,  4.24s/it]
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :   5% 0.04759161569119106/1 [00:00<00:13, 13.98s/it]
# libcusparse-12.0.2.5 | 163.0 MB  | :  10% 0.09799301351448088/1 [00:01<00:06,  6.70s/it]
#
# mkl-2023.2.0         | 156.8 MB  | :  14% 0.14108951756139015/1 [00:01<00:04,  5.61s/it]
#
#
#
# libcufft-11.0.2.4    | 102.9 MB  | :  18% 0.17648351438300364/1 [00:01<00:03,  4.02s/it]
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :   6% 0.05979824765988977/1 [00:01<00:10, 11.67s/it]
# libcusparse-12.0.2.5 | 163.0 MB  | :  12% 0.11640265988902132/1 [00:01<00:05,  6.31s/it]
#
# mkl-2023.2.0         | 156.8 MB  | :  16% 0.16091777603223523/1 [00:01<00:04,  5.54s/it]
#
#
#
# libcufft-11.0.2.4    | 102.9 MB  | :  21% 0.20974503731749397/1 [00:01<00:02,  3.68s/it]
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :   7% 0.06953505526138096/1 [00:01<00:10, 11.76s/it]
# libcusparse-12.0.2.5 | 163.0 MB  | :  13% 0.13452465553895956/1 [00:01<00:05,  6.48s/it]
#
# mkl-2023.2.0         | 156.8 MB  | :  18% 0.18303774276855486/1 [00:01<00:04,  5.22s/it]
#
#
#
# libcufft-11.0.2.4    | 102.9 MB  | :  24% 0.24209528565103938/1 [00:01<00:02,  3.50s/it]
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :   8% 0.07884439326085545/1 [00:01<00:11, 12.28s/it]
# libcusparse-12.0.2.5 | 163.0 MB  | :  15% 0.15149604829048902/1 [00:01<00:05,  6.40s/it]
#
# mkl-2023.2.0         | 156.8 MB  | :  20% 0.20336419868841615/1 [00:01<00:04,  5.50s/it]
#
#
#
# libcufft-11.0.2.4    | 102.9 MB  | :  27% 0.27247110568253746/1 [00:01<00:02,  3.71s/it]
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :   9% 0.08758377179097437/1 [00:01<00:11, 12.22s/it]
# libcusparse-12.0.2.5 | 163.0 MB  | :  17% 0.16952216036555987/1 [00:01<00:05,  6.19s/it]
#
# mkl-2023.2.0         | 156.8 MB  | :  22% 0.22388993358788392/1 [00:01<00:04,  5.37s/it]
#
#
# libnpp-12.0.2.50     | 139.8 MB  | :  22% 0.22281579910710628/1 [00:01<00:03,  4.83s/it]
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  10% 0.09751056588225075/1 [00:01<00:10, 11.54s/it]
# libcusparse-12.0.2.5 | 163.0 MB  | :  19% 0.1882194574647025/1 [00:01<00:04,  5.97s/it]
#
#
#
# libcufft-11.0.2.4    | 102.9 MB  | :  34% 0.3353490531477384/1 [00:01<00:02,  3.49s/it]
#
# mkl-2023.2.0         | 156.8 MB  | :  25% 0.24690665573243276/1 [00:01<00:03,  5.16s/it]
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  11% 0.10653492414704746/1 [00:01<00:10, 11.43s/it]
# libcusparse-12.0.2.5 | 163.0 MB  | :  21% 0.20557438451570156/1 [00:01<00:04,  5.92s/it]
#
#
#
# libcufft-11.0.2.4    | 102.9 MB  | :  37% 0.3705850043842761/1 [00:01<00:02,  3.28s/it]
#
#
# libnpp-12.0.2.50     | 139.8 MB  | :  27% 0.2675354778039665/1 [00:01<00:03,  4.73s/it]
#
# libcublas-12.1.0.26  | 329.0 MB  | :  12% 0.11551178578939787/1 [00:01<00:10, 12.01s/it]
# libcusparse-12.0.2.5 | 163.0 MB  | :  22% 0.224463448764579/1 [00:01<00:04,  5.76s/it]
#
# mkl-2023.2.0         | 156.8 MB  | :  29% 0.2905487522662526/1 [00:01<00:03,  4.88s/it]
#
#
# libnpp-12.0.2.50     | 139.8 MB  | :  29% 0.28944812036542805/1 [00:01<00:03,  4.73s/it]
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  12% 0.12439365418685568/1 [00:01<00:10, 11.85s/it]
# libcusparse-12.0.2.5 | 163.0 MB  | :  24% 0.24335251301345642/1 [00:01<00:04,  5.63s/it]
#
#
# libnpp-12.0.2.50     | 139.8 MB  | :  31% 0.31080176694317885/1 [00:01<00:03,  4.73s/it]
#
# mkl-2023.2.0         | 156.8 MB  | :  31% 0.31137340563513005/1 [00:01<00:03,  4.92s/it]
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  13% 0.1329905428496357/1 [00:01<00:10, 12.00s/it]
# libcusparse-12.0.2.5 | 163.0 MB  | :  27% 0.26665222170623415/1 [00:01<00:03,  5.18s/it]
#
#
# libnpp-12.0.2.50     | 139.8 MB  | :  33% 0.33293800789812467/1 [00:02<00:03,  4.84s/it]
#
# mkl-2023.2.0         | 156.8 MB  | :  33% 0.3320984195142043/1 [00:02<00:03,  5.06s/it]
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  14% 0.14296483356335837/1 [00:02<00:09, 11.40s/it]
# libcusparse-12.0.2.5 | 163.0 MB  | :  29% 0.28803425890166395/1 [00:02<00:03,  5.08s/it]
#
#
# libnpp-12.0.2.50     | 139.8 MB  | :  36% 0.3555214456400391/1 [00:02<00:03,  4.72s/it]
#
# mkl-2023.2.0         | 156.8 MB  | :  35% 0.35272379390347536/1 [00:02<00:03,  5.01s/it]
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  16% 0.15559893513407377/1 [00:02<00:08, 10.11s/it]
# libcusparse-12.0.2.5 | 163.0 MB  | :  31% 0.3078821588992154/1 [00:02<00:03,  5.40s/it]
#
#
# libnpp-12.0.2.50     | 139.8 MB  | :  38% 0.3820178552679288/1 [00:02<00:02,  4.41s/it]
#
# mkl-2023.2.0         | 156.8 MB  | :  37% 0.37285097084373015/1 [00:02<00:03,  5.05s/it]
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  17% 0.16562072247024276/1 [00:02<00:08, 10.73s/it]
# libcusparse-12.0.2.5 | 163.0 MB  | :  33% 0.32667533957322537/1 [00:02<00:03,  5.64s/it]
#
#
# libnpp-12.0.2.50     | 139.8 MB  | :  40% 0.40482489140332756/1 [00:02<00:02,  4.50s/it]
#
# mkl-2023.2.0         | 156.8 MB  | :  39% 0.3927788688043785/1 [00:02<00:03,  5.20s/it]
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  18% 0.17815983079606554/1 [00:02<00:08,  9.97s/it]
# libcusparse-12.0.2.5 | 163.0 MB  | :  36% 0.35563217918317963/1 [00:02<00:03,  4.84s/it]
#
# mkl-2023.2.0         | 156.8 MB  | :  41% 0.4122085693160106/1 [00:02<00:03,  5.20s/it]
#
#
#
# libcufft-11.0.2.4    | 102.9 MB  | :  59% 0.5886833922104321/1 [00:02<00:01,  3.15s/it]
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  19% 0.19050895263210313/1 [00:02<00:07,  9.36s/it]
#
#
#
# libcufft-11.0.2.4    | 102.9 MB  | :  62% 0.6219449151449224/1 [00:02<00:01,  3.12s/it]
# libcusparse-12.0.2.5 | 163.0 MB  | :  38% 0.3766306820791398/1 [00:02<00:03,  5.31s/it]
#
# mkl-2023.2.0         | 156.8 MB  | :  43% 0.43153863033783946/1 [00:02<00:03,  5.43s/it]
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  20% 0.2013381825498592/1 [00:02<00:08, 10.64s/it]
#
# mkl-2023.2.0         | 156.8 MB  | :  45% 0.45007157544124243/1 [00:02<00:03,  5.88s/it]
# libcusparse-12.0.2.5 | 163.0 MB  | :  40% 0.39599916420235426/1 [00:02<00:03,  5.78s/it]
#
#
#
# libcufft-11.0.2.4    | 102.9 MB  | :  65% 0.6542951634784678/1 [00:02<00:01,  3.47s/it]
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  21% 0.21107499015135037/1 [00:02<00:08, 10.77s/it]
#
# mkl-2023.2.0         | 156.8 MB  | :  47% 0.4675084861568097/1 [00:02<00:03,  5.89s/it]
# libcusparse-12.0.2.5 | 163.0 MB  | :  41% 0.4138335091276903/1 [00:02<00:03,  5.80s/it]
#
#
# libnpp-12.0.2.50     | 139.8 MB  | :  49% 0.4887860881566827/1 [00:02<00:02,  5.16s/it]
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  22% 0.22062181126305636/1 [00:02<00:09, 12.01s/it]
#
#
# libnpp-12.0.2.50     | 139.8 MB  | :  51% 0.5083509475865591/1 [00:02<00:02,  5.16s/it]
# libcusparse-12.0.2.5 | 163.0 MB  | :  43% 0.43147608690329153/1 [00:02<00:03,  5.99s/it]
#
# mkl-2023.2.0         | 156.8 MB  | :  48% 0.48464647840296726/1 [00:02<00:03,  6.24s/it]
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  23% 0.23335090607866435/1 [00:02<00:08, 10.59s/it]
#
#
# libnpp-12.0.2.50     | 139.8 MB  | :  53% 0.5279158070164355/1 [00:02<00:02,  5.28s/it]
#
# mkl-2023.2.0         | 156.8 MB  | :  50% 0.5031794235063702/1 [00:03<00:02,  5.98s/it]
# libcusparse-12.0.2.5 | 163.0 MB  | :  45% 0.4510363361762407/1 [00:03<00:03,  5.75s/it]
#
#
#
# libcufft-11.0.2.4    | 102.9 MB  | :  74% 0.7411700087685522/1 [00:03<00:00,  3.67s/it]
#
#
# libnpp-12.0.2.50     | 139.8 MB  | :  55% 0.549157654397444/1 [00:03<00:02,  5.10s/it]
# libcusparse-12.0.2.5 | 163.0 MB  | :  47% 0.4714595376229965/1 [00:03<00:02,  5.49s/it]
#
# libcublas-12.1.0.26  | 329.0 MB  | :  24% 0.24323020354749444/1 [00:03<00:08, 11.45s/it]
#
#
#
# libcufft-11.0.2.4    | 102.9 MB  | :  77% 0.7735202571020976/1 [00:03<00:00,  3.49s/it]
#
#
# libnpp-12.0.2.50     | 139.8 MB  | :  57% 0.5692815098110312/1 [00:03<00:02,  5.06s/it]
# libcusparse-12.0.2.5 | 163.0 MB  | :  49% 0.49169097192001754/1 [00:03<00:02,  5.36s/it]
#
# mkl-2023.2.0         | 156.8 MB  | :  54% 0.5394481977947502/1 [00:03<00:02,  5.83s/it]
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  25% 0.25458189631215977/1 [00:03<00:07, 10.63s/it]
#
#
# libnpp-12.0.2.50     | 139.8 MB  | :  59% 0.5895171644213605/1 [00:03<00:02,  5.03s/it]
# libcusparse-12.0.2.5 | 163.0 MB  | :  51% 0.510580036168895/1 [00:03<00:02,  5.51s/it]
#
# mkl-2023.2.0         | 156.8 MB  | :  56% 0.5567854690205142/1 [00:03<00:02,  5.93s/it]
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  26% 0.2643662005360973/1 [00:03<00:07, 10.72s/it]
#
#
#
# libcufft-11.0.2.4    | 102.9 MB  | :  88% 0.8781649571106084/1 [00:03<00:00,  5.50s/it]
#
# mkl-2023.2.0         | 156.8 MB  | :  57% 0.5738238217768685/1 [00:03<00:04, 10.50s/it]
#
#
# libnpp-12.0.2.50     | 139.8 MB  | :  61% 0.6095292206382054/1 [00:03<00:03,  9.34s/it]
# libcublas-12.1.0.26  | 329.0 MB  | :  27% 0.27396051827024953/1 [00:03<00:14, 19.68s/it]
#
#
#
# libcufft-11.0.2.4    | 102.9 MB  | :  91% 0.9138565456476186/1 [00:03<00:00,  4.66s/it]
#
# mkl-2023.2.0         | 156.8 MB  | :  60% 0.5981358572888594/1 [00:03<00:03,  8.14s/it]
#
#
# libnpp-12.0.2.50     | 139.8 MB  | :  63% 0.6302120720355033/1 [00:03<00:02,  7.97s/it]
# libcublas-12.1.0.26  | 329.0 MB  | :  28% 0.28279489004526104/1 [00:03<00:12, 17.43s/it]
#
#
# libnpp-12.0.2.50     | 139.8 MB  | :  65% 0.6526837105806755/1 [00:03<00:02,  6.85s/it]
#
#
#
# libcufft-11.0.2.4    | 102.9 MB  | :  95% 0.9454473984803765/1 [00:03<00:00,  4.32s/it]
#
# libcublas-12.1.0.26  | 329.0 MB  | :  29% 0.2943365692997116/1 [00:03<00:10, 14.50s/it]
# libcusparse-12.0.2.5 | 163.0 MB  | :  57% 0.5710825719102232/1 [00:03<00:03,  7.65s/it]
#
#
# libnpp-12.0.2.50     | 139.8 MB  | :  68% 0.6788447226183388/1 [00:03<00:01,  5.80s/it]
#
#
#
# libcufft-11.0.2.4    | 102.9 MB  | :  98% 0.9755194603115597/1 [00:03<00:00,  4.05s/it]
#
# libcublas-12.1.0.26  | 329.0 MB  | :  30% 0.303313430942062/1 [00:04<00:09, 13.70s/it]
# libcusparse-12.0.2.5 | 163.0 MB  | :  59% 0.5879580810868853/1 [00:04<00:02,  7.27s/it]
#
#
# libnpp-12.0.2.50     | 139.8 MB  | :  70% 0.7013163611635111/1 [00:04<00:01,  5.43s/it]
#
# libcublas-12.1.0.26  | 329.0 MB  | :  32% 0.3161850156250089/1 [00:04<00:08, 11.71s/it]
# libcusparse-12.0.2.5 | 163.0 MB  | :  60% 0.6045459395389451/1 [00:04<00:02,  6.97s/it]
#
#
# libnpp-12.0.2.50     | 139.8 MB  | :  74% 0.7367567065307729/1 [00:04<00:01,  4.38s/it]
#
# mkl-2023.2.0         | 156.8 MB  | :  68% 0.6760539383149944/1 [00:04<00:01,  5.91s/it]
# libcublas-12.1.0.26  | 329.0 MB  | :  33% 0.3261118097162853/1 [00:04<00:07, 11.62s/it]
#
#
# libnpp-12.0.2.50     | 139.8 MB  | :  76% 0.7622469233879832/1 [00:04<00:01,  4.48s/it]
#
# mkl-2023.2.0         | 156.8 MB  | :  70% 0.6999674158677724/1 [00:04<00:01,  5.48s/it]
# libcublas-12.1.0.26  | 329.0 MB  | :  34% 0.33803346195030615/1 [00:04<00:07, 10.79s/it]
#
#
# libnpp-12.0.2.50     | 139.8 MB  | :  79% 0.7865073490810299/1 [00:04<00:01,  4.76s/it]
#
# mkl-2023.2.0         | 156.8 MB  | :  72% 0.722884498522518/1 [00:04<00:01,  5.17s/it]
# libcublas-12.1.0.26  | 329.0 MB  | :  35% 0.34805524928647513/1 [00:04<00:07, 11.03s/it]
#
#
# libnpp-12.0.2.50     | 139.8 MB  | :  81% 0.8089789876262022/1 [00:04<00:00,  4.70s/it]
#
# mkl-2023.2.0         | 156.8 MB  | :  74% 0.7433105939321826/1 [00:04<00:01,  5.14s/it]
# libcublas-12.1.0.26  | 329.0 MB  | :  36% 0.36021438463272754/1 [00:04<00:06, 10.16s/it]
#
#
# libnpp-12.0.2.50     | 139.8 MB  | :  84% 0.837823180385677/1 [00:04<00:00,  4.30s/it]
#
# mkl-2023.2.0         | 156.8 MB  | :  77% 0.7664269555665346/1 [00:04<00:01,  4.90s/it]
# libcublas-12.1.0.26  | 329.0 MB  | :  37% 0.3705211517035743/1 [00:04<00:06, 10.63s/it]
#
#
# libnpp-12.0.2.50     | 139.8 MB  | :  86% 0.8643195900135667/1 [00:04<00:00,  4.19s/it]
# libcusparse-12.0.2.5 | 163.0 MB  | :  73% 0.7311122583639107/1 [00:04<00:01,  4.80s/it]
#
# libcublas-12.1.0.26  | 329.0 MB  | :  38% 0.3828227769171656/1 [00:04<00:06,  9.88s/it]
#
#
# libnpp-12.0.2.50     | 139.8 MB  | :  89% 0.8889154132968399/1 [00:04<00:00,  4.28s/it]
# libcusparse-12.0.2.5 | 163.0 MB  | :  75% 0.753836665607484/1 [00:04<00:01,  4.69s/it]
#
# libcublas-12.1.0.26  | 329.0 MB  | :  39% 0.39412697305938466/1 [00:04<00:05,  9.57s/it]
# libcusparse-12.0.2.5 | 163.0 MB  | :  78% 0.77646518927619/1 [00:04<00:01,  4.69s/it]
#
# mkl-2023.2.0         | 156.8 MB  | :  83% 0.8329861347551/1 [00:04<00:00,  4.77s/it]
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  40% 0.4048137131098018/1 [00:05<00:06, 10.82s/it]
# libcusparse-12.0.2.5 | 163.0 MB  | :  80% 0.8000525486935699/1 [00:05<00:00,  4.56s/it]
#
# mkl-2023.2.0         | 156.8 MB  | :  86% 0.8558035779200424/1 [00:05<00:00,  4.66s/it]
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  42% 0.41849274037433576/1 [00:05<00:05,  9.78s/it]
#
# mkl-2023.2.0         | 156.8 MB  | :  88% 0.8776246261869523/1 [00:05<00:00,  4.69s/it]
# libcusparse-12.0.2.5 | 163.0 MB  | :  82% 0.8222016544879389/1 [00:05<00:00,  4.96s/it]
#
#
# libnpp-12.0.2.50     | 139.8 MB  | :  96% 0.9618084895727221/1 [00:05<00:00,  4.64s/it]
#
# libcublas-12.1.0.26  | 329.0 MB  | :  43% 0.4290844871798603/1 [00:05<00:06, 10.56s/it]
# libcusparse-12.0.2.5 | 163.0 MB  | :  84% 0.8428166230844295/1 [00:05<00:00,  5.17s/it]
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  44% 0.4389162880262441/1 [00:05<00:06, 10.92s/it]
#
# mkl-2023.2.0         | 156.8 MB  | :  92% 0.9201706883329364/1 [00:05<00:00,  5.15s/it]
# libcusparse-12.0.2.5 | 163.0 MB  | :  86% 0.862472755932246/1 [00:05<00:00,  5.77s/it]
#
# libcublas-12.1.0.26  | 329.0 MB  | :  45% 0.44832061927061123/1 [00:05<00:06, 11.31s/it]
# libcusparse-12.0.2.5 | 163.0 MB  | :  88% 0.8818412380554606/1 [00:05<00:00,  5.70s/it]
#
# libcublas-12.1.0.26  | 329.0 MB  | :  46% 0.458152420116995/1 [00:05<00:05, 11.02s/it]
# libcusparse-12.0.2.5 | 163.0 MB  | :  90% 0.9004426515797357/1 [00:05<00:00,  5.61s/it]
#
# libcublas-12.1.0.26  | 329.0 MB  | :  47% 0.4701215689734622/1 [00:05<00:05, 10.23s/it]
# libcublas-12.1.0.26  | 329.0 MB  | :  48% 0.4800483630647386/1 [00:05<00:05, 10.33s/it]
# libcublas-12.1.0.26  | 329.0 MB  | :  49% 0.49016514364580016/1 [00:05<00:05, 10.24s/it]
# libcublas-12.1.0.26  | 329.0 MB  | :  50% 0.5000444411146302/1 [00:06<00:05, 10.29s/it]
# libcublas-12.1.0.26  | 329.0 MB  | :  54% 0.5362368674187097/1 [00:06<00:04,  9.02s/it]
#
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  55% 0.5513407933566326/1 [00:06<00:03,  8.15s/it]
#
#
#
#
# libcusolver-11.4.4.5 | 98.3 MB   | :   3% 0.030839160569120956/1 [00:06<02:23, 148.15s/it]
#
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  56% 0.5636899151926702/1 [00:06<00:04,  9.36s/it]
#
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  57% 0.574804124845104/1 [00:06<00:04,  9.54s/it]
#
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  59% 0.5855858581404138/1 [00:06<00:04, 10.40s/it]
#
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  60% 0.5955126522316901/1 [00:06<00:04, 10.39s/it]
#
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  61% 0.608051760557513/1 [00:07<00:03,  9.73s/it]
#
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  62% 0.6185485141181449/1 [00:07<00:03,  9.72s/it]
#
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  63% 0.631610085290877/1 [00:07<00:03,  9.05s/it]
#
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  64% 0.6428192881882034/1 [00:07<00:03,  9.51s/it]
#
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  65% 0.6535060282386206/1 [00:07<00:03,  9.93s/it]
#
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  66% 0.6637178020645748/1 [00:07<00:04, 12.14s/it]
#
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  67% 0.6725521738395862/1 [00:07<00:04, 12.85s/it]
#
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  68% 0.6821464915737385/1 [00:07<00:03, 12.23s/it]
#
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  69% 0.6906958836140723/1 [00:08<00:04, 12.96s/it]
#
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  70% 0.7001952081033319/1 [00:08<00:03, 12.30s/it]
#
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  71% 0.7104544785517324/1 [00:08<00:03, 11.91s/it]
#
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  72% 0.7201437895307773/1 [00:08<00:03, 11.46s/it]
#
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  73% 0.7290731545506814/1 [00:08<00:03, 11.60s/it]
#
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  74% 0.7411847932744875/1 [00:08<00:02, 10.48s/it]
#
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  75% 0.7508741042535324/1 [00:08<00:02, 11.01s/it]
#
#
#
#
#
# qt-main-5.15.8       | 58.0 MB   | :   0% 0.0002692551269896843/1 [00:08<8:59:13, 32362.14s/it]
#
#
#
#
# libcusolver-11.4.4.5 | 98.3 MB   | :  70% 0.695947654492843/1 [00:08<00:01,  3.86s/it]
#
#
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  76% 0.7600884490081143/1 [00:08<00:03, 12.71s/it]
#
#
#
#
# libcusolver-11.4.4.5 | 98.3 MB   | :  72% 0.7228126964319226/1 [00:08<00:01,  3.93s/it]
#
#
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  77% 0.769112807272911/1 [00:08<00:02, 12.28s/it]
#
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  78% 0.7779946756703688/1 [00:09<00:02, 11.99s/it]
#
#
#
#
#
# qt-main-5.15.8       | 58.0 MB   | :  13% 0.1338197981138731/1 [00:09<00:28, 32.65s/it]
#
#
#
#
# libcusolver-11.4.4.5 | 98.3 MB   | :  79% 0.7857627355317778/1 [00:09<00:00,  3.68s/it]
#
#
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  79% 0.7865915643331489/1 [00:09<00:02, 12.07s/it]
#
#
#
#
# libcusolver-11.4.4.5 | 98.3 MB   | :  82% 0.8159660371200921/1 [00:09<00:00,  3.79s/it]
#
#
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  80% 0.7952834462408215/1 [00:09<00:02, 11.91s/it]
#
#
#
#
# libcusolver-11.4.4.5 | 98.3 MB   | :  85% 0.8464872681988097/1 [00:09<00:00,  3.64s/it]
#
#
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  80% 0.8038328382811553/1 [00:09<00:02, 13.22s/it]
#
#
#
#
#
#
# llvm-openmp-18.1.2   | 57.6 MB   | :   0% 0.0002714265446280969/1 [00:09<9:39:59, 34809.07s/it]
#
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  81% 0.8129046931683982/1 [00:09<00:02, 12.55s/it]
#
#
#
#
#
# qt-main-5.15.8       | 58.0 MB   | :  33% 0.3341456125941982/1 [00:09<00:04,  7.23s/it]
#
#
#
#
#
#
# llvm-openmp-18.1.2   | 57.6 MB   | :   6% 0.061613825630578004/1 [00:09<01:42, 109.26s/it]
#
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  82% 0.821454085208732/1 [00:09<00:02, 12.36s/it]
#
#
#
#
#
# qt-main-5.15.8       | 58.0 MB   | :  38% 0.3826115354523414/1 [00:09<00:03,  5.61s/it]
#
#
#
#
#
#
# llvm-openmp-18.1.2   | 57.6 MB   | :   9% 0.09499929061983392/1 [00:09<00:56, 62.90s/it]
#
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  83% 0.8305734367184212/1 [00:09<00:02, 11.98s/it]
#
#
#
#
#
# qt-main-5.15.8       | 58.0 MB   | :  43% 0.43161596856446394/1 [00:09<00:02,  4.55s/it]
#
#
#
#
#
#
# llvm-openmp-18.1.2   | 57.6 MB   | :  15% 0.15471313043801524/1 [00:09<00:25, 30.63s/it]
#
#
#
#
# libcusolver-11.4.4.5 | 98.3 MB   | :  96% 0.9609418847440009/1 [00:09<00:00,  3.82s/it]
#
#
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  84% 0.8390753321363087/1 [00:09<00:02, 12.88s/it]
#
#
#
#
#
#
# llvm-openmp-18.1.2   | 57.6 MB   | :  20% 0.20031278993553553/1 [00:09<00:16, 20.27s/it]
#
#
#
#
# libcusolver-11.4.4.5 | 98.3 MB   | : 100% 0.9973448113951797/1 [00:09<00:00,  3.45s/it]
#
#
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  85% 0.8494295958296018/1 [00:09<00:01, 11.83s/it]
#
#
#
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  86% 0.858073981114828/1 [00:10<00:01, 13.20s/it]
#
#
#
#
#
# qt-main-5.15.8       | 58.0 MB   | :  58% 0.5775522473928728/1 [00:10<00:01,  3.24s/it]
#
#
#
#
#
#
# llvm-openmp-18.1.2   | 57.6 MB   | :  29% 0.2923263885644604/1 [00:10<00:07, 10.56s/it]
#
#
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  87% 0.8659584204409136/1 [00:10<00:02, 15.17s/it]
#
#
#
#
#
#
# llvm-openmp-18.1.2   | 57.6 MB   | :  33% 0.33195466408016255/1 [00:10<00:05,  8.27s/it]
#
#
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  87% 0.8736053766547677/1 [00:10<00:01, 14.67s/it]
#
#
#
#
#
#
# llvm-openmp-18.1.2   | 57.6 MB   | :  37% 0.3710400865066085/1 [00:10<00:04,  6.64s/it]
#
#
#
#
#
#
#
# libtorch-2.1.2       | 45.2 MB   | :   0% 0.00034544558231627294/1 [00:10<8:20:15, 30025.82s/it]
#
#
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  88% 0.8812523328686217/1 [00:10<00:01, 14.28s/it]
#
#
#
#
#
#
# llvm-openmp-18.1.2   | 57.6 MB   | :  41% 0.41175406820082305/1 [00:10<00:03,  5.43s/it]
#
#
#
#
#
#
#
# libtorch-2.1.2       | 45.2 MB   | :   6% 0.06356198714619422/1 [00:10<01:48, 116.07s/it]
#
#
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  89% 0.8885193161029054/1 [00:10<00:01, 14.96s/it]
#
#
#
#
#
#
# llvm-openmp-18.1.2   | 57.6 MB   | :  45% 0.4502966375380128/1 [00:10<00:02,  4.65s/it]
#
#
#
#
#
#
#
# libtorch-2.1.2       | 45.2 MB   | :  12% 0.12401496405154198/1 [00:10<00:43, 50.16s/it]
#
#
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  90% 0.8954063263576186/1 [00:10<00:01, 15.45s/it]
#
#
#
#
#
#
# llvm-openmp-18.1.2   | 57.6 MB   | :  50% 0.5032248137404917/1 [00:10<00:01,  3.75s/it]
#
#
#
#
#
# qt-main-5.15.8       | 58.0 MB   | :  85% 0.8459996090015881/1 [00:10<00:00,  2.35s/it]
#
#
#
#
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  90% 0.9024358264796708/1 [00:10<00:01, 15.23s/it]
#
#
#
#
#
#
# llvm-openmp-18.1.2   | 57.6 MB   | :  55% 0.5458387812471029/1 [00:10<00:01,  3.34s/it]
#
#
#
#
#
#
#
# libtorch-2.1.2       | 45.2 MB   | :  24% 0.23593933272201442/1 [00:10<00:14, 19.15s/it]
#
#
#
#
#
# qt-main-5.15.8       | 58.0 MB   | :  89% 0.8909652152088653/1 [00:10<00:00,  2.63s/it]
#
#
#
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  91% 0.9091328502445989/1 [00:10<00:01, 16.55s/it]
#
#
#
#
#
#
#
# libtorch-2.1.2       | 45.2 MB   | :  29% 0.28637438774019025/1 [00:10<00:09, 13.52s/it]
#
#
#
#
#
#
# llvm-openmp-18.1.2   | 57.6 MB   | :  65% 0.6468094558487549/1 [00:10<00:00,  2.63s/it]
#
#
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  92% 0.9173972625502549/1 [00:11<00:01, 15.26s/it]
#
#
#
#
#
#
#
# libtorch-2.1.2       | 45.2 MB   | :  34% 0.33508221484678474/1 [00:11<00:06, 10.00s/it]
#
#
#
#
#
#
# llvm-openmp-18.1.2   | 57.6 MB   | :  69% 0.6940376746140439/1 [00:11<00:00,  2.49s/it]
#
#
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  93% 0.9251392120090015/1 [00:11<00:01, 14.98s/it]
#
#
#
#
#
#
#
# libtorch-2.1.2       | 45.2 MB   | :  39% 0.388626280105807/1 [00:11<00:04,  7.36s/it]
#
#
#
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  93% 0.9319787256412685/1 [00:11<00:01, 14.91s/it]
#
#
#
#
#
#
#
# libtorch-2.1.2       | 45.2 MB   | :  45% 0.44838836584652225/1 [00:11<00:03,  5.50s/it]
#
#
#
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | :  94% 0.9387707426510892/1 [00:11<00:00, 16.09s/it]
#
#
#
#
#
#
#
# ...
#
#
#
#
#
#
#
#
# libcurand-10.3.2.106 | 39.8 MB   | :   0% 0.00039252999887277/1 [00:13<9:32:27, 34360.60s/it]
#
#
#
#
#
#
#
#
# libcurand-10.3.2.106 | 39.8 MB   | :   6% 0.060057089827533806/1 [00:13<02:29, 159.23s/it]
#
#
#
#
#
#
#
#
#
# pillow-10.2.0        | 39.7 MB   | :   0% 0.0003935697467855268/1 [00:13<9:37:11, 34644.76s/it]
#
#
#
#
#
#
#
#
# libcurand-10.3.2.106 | 39.8 MB   | :  12% 0.11815152966070377/1 [00:13<00:59, 68.03s/it]
#
#
#
#
#
#
#
#
#
# pillow-10.2.0        | 39.7 MB   | :   4% 0.039356974678552675/1 [00:13<03:56, 246.14s/it]
#
#
#
#
#
#
#
#
#
# pillow-10.2.0        | 39.7 MB   | :   7% 0.07399111239567903/1 [00:13<01:42, 110.51s/it]
#
#
#
#
#
#
#
#
# libcurand-10.3.2.106 | 39.8 MB   | :  17% 0.16957295951303664/1 [00:13<00:33, 40.50s/it]
#
#
#
#
#
#
#
#
#
# pillow-10.2.0        | 39.7 MB   | :  12% 0.12476160973101198/1 [00:13<00:45, 52.07s/it]
#
#
#
#
#
#
#
#
# libcurand-10.3.2.106 | 39.8 MB   | :  27% 0.2680979892301019/1 [00:13<00:14, 19.35s/it]
#
#
#
#
#
#
#
#
#
#
# libllvm18-18.1.2     | 36.6 MB   | :   0% 0.00042658323853850456/1 [00:14<9:08:54, 32948.23s/it]
#
#
#
#
#
#
#
#
#
# pillow-10.2.0        | 39.7 MB   | :  17% 0.1692349911177765/1 [00:14<00:26, 32.09s/it]
#
#
#
#
#
#
#
#
# libcurand-10.3.2.106 | 39.8 MB   | :  33% 0.33011772905199954/1 [00:14<00:09, 13.95s/it]
#
#
#
#
#
#
#
#
#
#
# libllvm18-18.1.2     | 36.6 MB   | :   5% 0.052896321578774566/1 [00:14<02:58, 188.40s/it]
#
#
#
#
#
#
#
#
#
# pillow-10.2.0        | 39.7 MB   | :  21% 0.2101662447834713/1 [00:14<00:17, 21.88s/it]
#
#
#
#
#
#
#
#
#
#
#
# libllvm15-15.0.7     | 31.8 MB   | :   0% 0.0004916951860778477/1 [00:14<8:03:04, 28998.99s/it]
#
#
#
#
#
#
#
#
#
#
# libllvm18-18.1.2     | 36.6 MB   | :  11% 0.10792555935024166/1 [00:14<01:08, 76.87s/it]
#
#
#
#
#
#
#
#
# libcurand-10.3.2.106 | 39.8 MB   | :  38% 0.3831092788998235/1 [00:14<00:06, 10.64s/it]
#
#
#
#
#
#
#
#
#
# pillow-10.2.0        | 39.7 MB   | :  26% 0.2589688933848766/1 [00:14<00:10, 14.64s/it]
#
#
#
#
#
#
#
#
# libcurand-10.3.2.106 | 39.8 MB   | :  43% 0.43335311875553806/1 [00:14<00:04,  8.24s/it]
#
#
#
#
#
#
#
#
#
#
# libllvm18-18.1.2     | 36.6 MB   | :  16% 0.15954213121340072/1 [00:14<00:36, 43.57s/it]
#
#
#
#
#
#
#
#
#
#
#
# libllvm15-15.0.7     | 31.8 MB   | :   6% 0.05949511751541957/1 [00:14<02:39, 170.12s/it]
#
#
#
#
#
#
#
#
#
# pillow-10.2.0        | 39.7 MB   | :  31% 0.308558681479853/1 [00:14<00:07, 10.28s/it]
#
#
#
#
#
#
#
#
# libcurand-10.3.2.106 | 39.8 MB   | :  50% 0.49929815856616344/1 [00:14<00:02,  5.94s/it]
#
#
#
#
#
#
#
#
#
#
# libllvm18-18.1.2     | 36.6 MB   | :  22% 0.2222498672785609/1 [00:14<00:19, 25.28s/it]
#
#
#
#
#
#
#
#
#
#
#
# libllvm15-15.0.7     | 31.8 MB   | :  13% 0.125873967635929/1 [00:14<00:58, 66.42s/it]
#
#
#
#
#
#
#
#
#
# pillow-10.2.0        | 39.7 MB   | :  36% 0.3605098880555425/1 [00:14<00:04,  7.42s/it]
#
#
#
#
#
#
#
#
#
#
#
# libllvm15-15.0.7     | 31.8 MB   | :  19% 0.18635247552350426/1 [00:14<00:30, 37.62s/it]
#
#
#
#
#
#
#
#
#
#
# libllvm18-18.1.2     | 36.6 MB   | :  32% 0.32121717861949395/1 [00:14<00:09, 13.30s/it]
#
#
#
#
#
#
#
#
# libcurand-10.3.2.106 | 39.8 MB   | :  55% 0.5542523584083512/1 [00:14<00:02,  4.81s/it]
#
#
#
#
#
#
#
#
#
# pillow-10.2.0        | 39.7 MB   | :  43% 0.4262360357687255/1 [00:14<00:02,  5.17s/it]
#
#
#
#
#
#
#
#
#
#
#
# libllvm15-15.0.7     | 31.8 MB   | :  27% 0.2723991330871276/1 [00:14<00:14, 20.33s/it]
#
#
#
#
#
#
#
#
#
#
# libllvm18-18.1.2     | 36.6 MB   | :  39% 0.39416291240957824/1 [00:14<00:05,  9.21s/it]
#
#
#
#
#
#
#
#
# libcurand-10.3.2.106 | 39.8 MB   | :  63% 0.6256928182031953/1 [00:14<00:01,  3.62s/it]
#
#
#
#
#
#
#
#
#
# pillow-10.2.0        | 39.7 MB   | :  49% 0.4876329162672677/1 [00:14<00:02,  4.03s/it]
#
#
#
#
#
#
#
#
#
#
#
# libllvm15-15.0.7     | 31.8 MB   | :  37% 0.3727049510470085/1 [00:14<00:07, 11.83s/it]
#
#
#
#
#
#
#
#
# libcurand-10.3.2.106 | 39.8 MB   | :  68% 0.684179788035238/1 [00:14<00:00,  3.08s/it]
#
#
#
#
#
#
#
#
#
# pillow-10.2.0        | 39.7 MB   | :  54% 0.543913390057598/1 [00:14<00:01,  3.34s/it]
#
#
#
#
#
#
#
#
#
#
# libllvm18-18.1.2     | 36.6 MB   | :  46% 0.4636959802913545/1 [00:14<00:03,  6.90s/it]
#
#
#
#
#
#
#
#
#
#
#
# libllvm15-15.0.7     | 31.8 MB   | :  45% 0.45088448563338634/1 [00:14<00:04,  8.38s/it]
#
#
#
#
#
#
#
#
# libcurand-10.3.2.106 | 39.8 MB   | :  74% 0.742274227868408/1 [00:14<00:00,  2.77s/it]
#
#
#
#
#
#
#
#
#
#
# libllvm18-18.1.2     | 36.6 MB   | :  56% 0.5558379598156714/1 [00:14<00:02,  4.72s/it]
#
#
#
#
#
#
#
#
#
# pillow-10.2.0        | 39.7 MB   | :  61% 0.6135752352386362/1 [00:14<00:01,  2.76s/it]
#
#
#
#
#
#
#
#
#
#
#
# libllvm15-15.0.7     | 31.8 MB   | :  54% 0.5447982661742552/1 [00:14<00:02,  5.75s/it]
#
#
#
#
#
#
#
#
# libcurand-10.3.2.106 | 39.8 MB   | :  81% 0.8148922776598705/1 [00:15<00:00,  2.37s/it]
#
#
#
#
#
#
#
#
#
# pillow-10.2.0        | 39.7 MB   | :  68% 0.68363065016646/1 [00:15<00:00,  2.32s/it]
#
#
#
#
#
#
#
#
#
#
# libllvm18-18.1.2     | 36.6 MB   | :  65% 0.6496862722941424/1 [00:15<00:01,  3.44s/it]
#
#
#
#
#
#
#
#
#
#
#
# libllvm15-15.0.7     | 31.8 MB   | :  65% 0.645595779320214/1 [00:15<00:01,  4.08s/it]
#
#
#
#
#
#
#
#
# libcurand-10.3.2.106 | 39.8 MB   | :  90% 0.8981086374208977/1 [00:15<00:00,  1.96s/it]
#
#
#
#
#
#
#
#
#
# pillow-10.2.0        | 39.7 MB   | :  77% 0.7654931574978496/1 [00:15<00:00,  1.93s/it]
#
#
#
#
#
#
#
#
#
#
# libllvm18-18.1.2     | 36.6 MB   | :  73% 0.7277510049466888/1 [00:15<00:00,  2.99s/it]
#
#
#
#
#
#
#
#
#
# pillow-10.2.0        | 39.7 MB   | :  83% 0.8316128749578181/1 [00:15<00:00,  1.83s/it]
#
#
#
#
#
#
#
#
# libcurand-10.3.2.106 | 39.8 MB   | :  96% 0.9628760872349048/1 [00:15<00:00,  1.92s/it]
#
#
#
#
#
#
#
#
#
#
#
# libllvm15-15.0.7     | 31.8 MB   | :  73% 0.7311507416977595/1 [00:15<00:00,  3.36s/it]
#
#
#
#
#
#
#
#
#
#
# libllvm18-18.1.2     | 36.6 MB   | :  80% 0.798137239305542/1 [00:15<00:00,  2.56s/it]
#
#
#
#
#
#
#
#
#
# pillow-10.2.0        | 39.7 MB   | :  92% 0.9162303705167063/1 [00:15<00:00,  1.60s/it]
#
#
#
#
#
#
#
#
#
#
#
# libllvm15-15.0.7     | 31.8 MB   | :  84% 0.8388319874488082/1 [00:15<00:00,  2.53s/it]
#
#
#
#
#
#
#
#
#
#
# libllvm18-18.1.2     | 36.6 MB   | :  88% 0.882600720536166/1 [00:15<00:00,  2.12s/it]
#
#
#
#
#
#
#
#
#
# pillow-10.2.0        | 39.7 MB   | :  99% 0.9874664946848867/1 [00:15<00:00,  1.65s/it]
#
#
#
#
#
#
#
#
#
#
#
# libllvm15-15.0.7     | 31.8 MB   | :  92% 0.9229118642681201/1 [00:15<00:00,  2.21s/it]
#
#
#
#
#
#
#
#
#
#
# libllvm18-18.1.2     | 36.6 MB   | :  96% 0.9568262040418658/1 [00:15<00:00,  1.95s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.11.8        | 29.3 MB   | :   0% 0.0005327417506725035/1 [00:16<8:28:56, 30552.37s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.2        | 27.8 MB   | :   0% 0.0005614877781136286/1 [00:16<8:04:52, 29109.01s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.11.8        | 29.3 MB   | :  11% 0.10708109188517322/1 [00:16<01:36, 107.64s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.1.105  | 17.1 MB   | :   0% 0.0009115538504721202/1 [00:16<5:00:16, 18032.66s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.2        | 27.8 MB   | :  11% 0.11398201895706661/1 [00:16<01:30, 101.62s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 16.5 MB   | :   0% 0.0009486857916642227/1 [00:16<4:49:36, 17393.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.11.8        | 29.3 MB   | :  20% 0.20137638175420633/1 [00:16<00:38, 48.28s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.1.105  | 17.1 MB   | :  21% 0.20601117020669918/1 [00:16<00:44, 56.42s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.2        | 27.8 MB   | :  22% 0.2156113067956334/1 [00:16<00:35, 45.23s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 16.5 MB   | :  23% 0.22863327579107767/1 [00:16<00:39, 51.04s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.11.8        | 29.3 MB   | :  29% 0.2898115123658419/1 [00:16<00:20, 28.24s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.2        | 27.8 MB   | :  31% 0.31331018018740475/1 [00:16<00:17, 26.01s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.1.105  | 17.1 MB   | :  41% 0.4083761250115099/1 [00:16<00:14, 23.90s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 16.5 MB   | :  45% 0.4468310078738489/1 [00:16<00:12, 21.89s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.11.8        | 29.3 MB   | :  37% 0.37238648372008/1 [00:16<00:11, 18.46s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.2        | 27.8 MB   | :  41% 0.40932459024483525/1 [00:16<00:09, 16.55s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.1.105  | 17.1 MB   | :  57% 0.5706327103955473/1 [00:16<00:06, 14.66s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.11.8        | 29.3 MB   | :  45% 0.4512322628196105/1 [00:16<00:07, 12.91s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 16.5 MB   | :  65% 0.6451063383316714/1 [00:16<00:04, 12.84s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.2        | 27.8 MB   | :  50% 0.5042160247460385/1 [00:16<00:05, 11.36s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.1.105  | 17.1 MB   | :  78% 0.7793785421536628/1 [00:16<00:01,  8.67s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.11.8        | 29.3 MB   | :  55% 0.5471257779406612/1 [00:16<00:03,  8.58s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 16.5 MB   | :  81% 0.8130237234562389/1 [00:16<00:01,  8.71s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.1.105  | 17.1 MB   | :  97% 0.9680701892013917/1 [00:17<00:00,  5.80s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.2        | 27.8 MB   | :  59% 0.586754728128742/1 [00:17<00:03,  8.37s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.11.8        | 29.3 MB   | :  65% 0.6499449358204543/1 [00:17<00:02,  5.86s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 16.5 MB   | :  97% 0.9686081932891714/1 [00:17<00:00,  6.22s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.2        | 27.8 MB   | :  69% 0.6872610404110814/1 [00:17<00:01,  5.83s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.11.8        | 29.3 MB   | :  74% 0.7362490994293999/1 [00:17<00:01,  4.52s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.2        | 27.8 MB   | :  79% 0.7860828893590801/1 [00:17<00:00,  4.28s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.11.8        | 29.3 MB   | :  82% 0.820955037786328/1 [00:17<00:00,  3.53s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.2        | 27.8 MB   | :  93% 0.9275778094437145/1 [00:17<00:00,  2.87s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.11.8        | 29.3 MB   | :  93% 0.9253724209181386/1 [00:17<00:00,  2.65s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libclang-cpp15-15.0. | 16.4 MB   | :   0% 0.0009522037204524223/1 [00:17<5:07:01, 18439.43s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.2.1         | 15.0 MB   | :   0% 0.001038560027394049/1 [00:17<4:42:35, 16972.81s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libclang-cpp15-15.0. | 16.4 MB   | :  23% 0.2266244854676765/1 [00:17<00:42, 54.74s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.2.1         | 15.0 MB   | :  20% 0.19732640520486935/1 [00:17<00:50, 63.14s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libclang-cpp15-15.0. | 16.4 MB   | :  45% 0.4522967672149006/1 [00:17<00:12, 22.91s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.2.1         | 15.0 MB   | :  39% 0.39361425038234465/1 [00:17<00:16, 26.51s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libclang-cpp15-15.0. | 16.4 MB   | :  65% 0.649402937348552/1 [00:17<00:04, 13.48s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.2.1         | 15.0 MB   | :  59% 0.590940655587214/1 [00:17<00:05, 14.64s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libclang-cpp15-15.0. | 16.4 MB   | :  83% 0.8322260516754171/1 [00:18<00:01,  8.83s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.2.1         | 15.0 MB   | :  78% 0.7841128206825071/1 [00:18<00:01,  9.17s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# pandas-2.2.1         | 15.0 MB   | :  98% 0.9824777859147705/1 [00:18<00:00,  6.02s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
# libcufft-11.0.2.4    | 102.9 MB  | : 100% 1.0/1 [00:49<00:00,  4.05s/it]
#
# mkl-2023.2.0         | 156.8 MB  | : 100% 1.0/1 [00:58<00:00,  4.99s/it]
#
#
# libnpp-12.0.2.50     | 139.8 MB  | : 100% 1.0/1 [01:12<00:00,  4.85s/it]
#
#
#
#
#
# qt-main-5.15.8       | 58.0 MB   | : 100% 1.0/1 [01:22<00:00,  2.79s/it]
# libcusparse-12.0.2.5 | 163.0 MB  | : 100% 1.0/1 [01:43<00:00,  4.16s/it]
#
#
#
#
#
#
# llvm-openmp-18.1.2   | 57.6 MB   | : 100% 1.0/1 [01:46<00:00,  2.39s/it]
#
#
#
#
#
#
#
# libtorch-2.1.2       | 45.2 MB   | : 100% 1.0/1 [01:53<00:00,  2.03s/it]
#
#
#
#
#
#
#
#
#
#
#
# libllvm15-15.0.7     | 31.8 MB   | : 100% 1.0/1 [01:54<00:00,  2.21s/it]
#
#
#
#
#
#
#
#
# libcurand-10.3.2.106 | 39.8 MB   | : 100% 1.0/1 [01:55<00:00,  1.92s/it]
#
#
#
#
#
#
#
#
#
# pillow-10.2.0        | 39.7 MB   | : 100% 1.0/1 [01:58<00:00,  1.65s/it]
#
#
#
#
#
#
#
#
#
#
# libllvm18-18.1.2     | 36.6 MB   | : 100% 1.0/1 [01:59<00:00,  1.95s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cuda-nvrtc-12.1.105  | 17.1 MB   | : 100% 1.0/1 [02:00<00:00,  5.80s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# scipy-1.12.0         | 16.5 MB   | : 100% 1.0/1 [02:02<00:00,  6.22s/it]
#
#
#
#
# libcusolver-11.4.4.5 | 98.3 MB   | : 100% 1.0/1 [02:07<00:00,  3.45s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
# pytorch-2.1.2        | 27.8 MB   | : 100% 1.0/1 [02:08<00:00,  2.87s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libclang-cpp15-15.0. | 16.4 MB   | : 100% 1.0/1 [02:09<00:00,  8.83s/it]
#
#
#
#
#
#
#
#
#
#
#
#
# python-3.11.8        | 29.3 MB   | : 100% 1.0/1 [02:11<00:00,  2.65s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  ... (more hidden) ...
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libcublas-12.1.0.26  | 329.0 MB  | : 100% 1.0/1 [03:33<00:00, 14.08s/it]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# done
# done
# done
# #
# # To activate this environment, use
# #
# #     $ conda activate musemotion_meta
# #
# # To deactivate an active environment, use
# #
# #     $ conda deactivate

# %%
# !conda init
# !conda activate musemotion_meta
# credit https://stackoverflow.com/a/62668276
# %%shell
eval "$(conda shell.bash hook)"
conda activate musemotion_meta

# %% [markdown]
# # Load data
# _Note_: tempo = bpm

# %%
import urllib.request
urllib.request.urlretrieve("https://github.com/zhandrew4/music-mood-classification/raw/main/muse_v3.csv", "datasets/muse_v3.csv")
urllib.request.urlretrieve("https://github.com/zhandrew4/music-mood-classification/raw/main/full_data.csv", "datasets/full_data.csv")
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# Cell In[1], line 2
#       1 import urllib.request
# ----> 2 urllib.request.urlretrieve("https://github.com/zhandrew4/music-mood-classification/raw/main/muse_v3.csv", "datasets/muse_v3.csv")
#       3 urllib.request.urlretrieve("https://github.com/zhandrew4/music-mood-classification/raw/main/full_data.csv", "datasets/full_data.csv")
#
# File c:\Users\17788\AppData\Local\Programs\Python\Python311\Lib\urllib\request.py:251, in urlretrieve(url, filename, reporthook, data)
#     249 # Handle temporary file setup.
#     250 if filename:
# --> 251     tfp = open(filename, 'wb')
#     252 else:
#     253     tfp = tempfile.NamedTemporaryFile(delete=False)
#
# PermissionError: [Errno 13] Permission denied: 'datasets/muse_v3.csv'

# %%
import pandas as pd
sample = pd.read_csv("datasets/full_data.csv", nrows=3)
sample.columns
# Out:
# Index(['Unnamed: 0', 'track', 'artist', 'seeds', 'spotify_id', 'danceability',
#        'energy', 'key', 'loudness', 'mode', 'speechiness', 'acousticness',
#        'instrumentalness', 'liveness', 'valence', 'tempo', 'type', 'id', 'uri',
#        'track_href', 'analysis_url', 'duration_ms', 'time_signature'],
#       dtype='object')

# %%
KEEP_COLS_MASTER = ["track", "album", "artist", "release_date", "length",
             "tempo", "key", "time_signature",
             "mood"]

KEEP_COLS_MODEL = ["track", "artist", "tempo", "key", "loudness", "time_signature", "duration_ms"]

# songs_df = pd.read_csv("data_moods.csv", usecols=KEEP_COLS_MASTER)
# make names the indices
songs_df = pd.read_csv("datasets/full_data.csv", usecols=KEEP_COLS_MODEL, parse_dates=True, infer_datetime_format=True)
songs_df.set_index("track", inplace=True)
songs_df
# Out:
# C:\Users\17788\AppData\Local\Temp\ipykernel_3696\842477347.py:9: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   songs_df = pd.read_csv("datasets/full_data.csv", usecols=KEEP_COLS_MODEL, parse_dates=True, infer_datetime_format=True)
#                                             artist  key  loudness    tempo  \
# track
# 'Till I Collapse                            Eminem    1    -3.237  171.447
# St. Anger                                Metallica    2    -2.642  185.252
# Speedin'                                 Rick Ross    1    -4.226  100.059
# Bamboo Banga                                M.I.A.    9    -4.554  125.984
# Die MF Die                                    Dope    5    -3.524  126.020
# ...                                            ...  ...       ...      ...
# Secret                                  Quietdrive    0    -5.126  167.996
# The Last of the Rest Was the End       Medications    2    -5.774  144.844
# Lovechild                            Daniel Lanois   10   -20.091   79.476
# Last Inhale                                 Tapage    2    -8.977  160.011
# Unfold                            Message To Bears    0   -11.355   96.970
#
#                                   duration_ms  time_signature
# track
# 'Till I Collapse                       297787               4
# St. Anger                              441133               4
# Speedin'                               204960               4
# Bamboo Banga                           298360               4
# Die MF Die                             186067               4
# ...                                       ...             ...
# Secret                                 258373               4
# The Last of the Rest Was the End       324000               3
# Lovechild                              516280               4
# Last Inhale                            324258               4
# Unfold                                 268440               4
#
# [61627 rows x 6 columns]

# %% [markdown]
# Convert dates to numbers, specfically seconds.
#
# _Note_: This goddamn dataset only gives the year for some songs.

# %%
# print(songs_df[songs_df["release_date"]=="1993"])
# # credit https://stackoverflow.com/a/54312941
# songs_df["release_date"] = pd.to_datetime(songs_df["release_date"], format="mixed").astype(int)/ 10**9
# songs_df["release_date"]

# %% [markdown]
# Load the V, A, D dimension values from the original MuSe dataset and add them to the rest of the data.
# ^ Join V, A, D columns by key columns title and author.

# %%
import pandas as pd

orig_dataset = pd.read_csv("datasets/muse_v3.csv")
orig_dataset.columns
orig_dataset.set_index("track", inplace=True)

# %%
VAL_COLS = ["valence_tags","arousal_tags","dominance_tags"]
songs_df = songs_df.join(orig_dataset[VAL_COLS], how="inner")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 2
#       1 VAL_COLS = ["valence_tags","arousal_tags","dominance_tags"]
# ----> 2 songs_df = songs_df.join(orig_dataset[VAL_COLS], how="inner")
#
# File c:\Users\17788\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\frame.py:10412, in DataFrame.join(self, other, on, how, lsuffix, rsuffix, sort, validate)
#   10402     if how == "cross":
#   10403         return merge(
#   10404             self,
#   10405             other,
#    (...)
#   10410             validate=validate,
#   10411         )
# > 10412     return merge(
#   10413         self,
#   10414         other,
#   10415         left_on=on,
#   10416         how=how,
#   10417         left_index=on is None,
#   10418         right_index=True,
#   10419         suffixes=(lsuffix, rsuffix),
#   10420         sort=sort,
#   10421         validate=validate,
#   10422     )
#   10423 else:
#   10424     if on is not None:
#
# File c:\Users\17788\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\merge.py:183, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     168 else:
#     169     op = _MergeOperation(
#     170         left_df,
#     171         right_df,
#    (...)
#     181         validate=validate,
#     182     )
# --> 183     return op.get_result(copy=copy)
#
# File c:\Users\17788\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\merge.py:885, in _MergeOperation.get_result(self, copy)
#     881     self.left, self.right = self._indicator_pre_merge(self.left, self.right)
#     883 join_index, left_indexer, right_indexer = self._get_join_info()
# --> 885 result = self._reindex_and_concat(
#     886     join_index, left_indexer, right_indexer, copy=copy
#     887 )
#     888 result = result.__finalize__(self, method=self._merge_type)
#     890 if self.indicator:
#
# File c:\Users\17788\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\merge.py:837, in _MergeOperation._reindex_and_concat(self, join_index, left_indexer, right_indexer, copy)
#     834 left = self.left[:]
#     835 right = self.right[:]
# --> 837 llabels, rlabels = _items_overlap_with_suffix(
#     838     self.left._info_axis, self.right._info_axis, self.suffixes
#     839 )
#     841 if left_indexer is not None and not is_range_indexer(left_indexer, len(left)):
#     842     # Pinning the index here (and in the right code just below) is not
#     843     #  necessary, but makes the `.take` more performant if we have e.g.
#     844     #  a MultiIndex for left.index.
#     845     lmgr = left._mgr.reindex_indexer(
#     846         join_index,
#     847         left_indexer,
#    (...)
#     852         use_na_proxy=True,
#     853     )
#
# File c:\Users\17788\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\reshape\merge.py:2661, in _items_overlap_with_suffix(left, right, suffixes)
#    2658 lsuffix, rsuffix = suffixes
#    2660 if not lsuffix and not rsuffix:
# -> 2661     raise ValueError(f"columns overlap but no suffix specified: {to_rename}")
#    2663 def renamer(x, suffix: str | None):
#    2664     """
#    2665     Rename the left and right indices.
#    2666
#    (...)
#    2677     x : renamed column name
#    2678     """
#
# ValueError: columns overlap but no suffix specified: Index(['valence_tags', 'arousal_tags', 'dominance_tags'], dtype='object')

# %% [markdown]
# Model will take data as (`X_train`,`y_train`)
# - `X_train` is a 2D NumPy array of shape `n_samples` x `n_features`, i.e. one song per row, one metadata feature per column
# - `y_train` is just convert the "mood" column into a 1D NumPy array

# %%
# How much should we take for training, testing?
songs_df.index.size

0.7 * songs_df.index.size
# Out:
# 77934.5

# %%
import numpy as np
from sklearn.model_selection import train_test_split

DROP_COLS = VAL_COLS+["artist"]
# use a constant random state for reproducibility
X_train, X_test, y_train, y_test = train_test_split(songs_df.drop(columns=DROP_COLS), songs_df[VAL_COLS],
                                                    test_size=0.2, random_state=42)

# %% [markdown]
# # Model
# ## Multi-Layer Perceptron
# [PyTorch tutorial](https://pytorch.org/tutorials/beginner/basics/buildmodel_tutorial.html)
#
# [Building a Regression Model in PyTorch](https://machinelearningmastery.com/building-a-regression-model-in-pytorch/)
#
# [ChatGPT Explaining The PyTorch Tutorial...](https://chat.openai.com/share/424f5717-901e-4dac-9f71-f30b1e4ab6de)

# %%
from sklearn.neural_network import MLPRegressor

mlp = MLPRegressor(solver='lbfgs', hidden_layer_sizes=())


mlp_regression = mlp.fit(X_train, y_train)
print(mlp_regression.score(X_test, y_test))
# Out:
# -0.9012068614978433

# %%
import os
import torch
from torch import nn
from torch.utils.data import DataLoader
from torchvision import datasets, transforms

# %%
device = (
    "cuda"
    if torch.cuda.is_available()
    else "mps"
    if torch.backends.mps.is_available()
    else "cpu"
)
print(f"Using {device} device")
# Out:
# Using cpu device

# %%
class NeuralNetwork(nn.Module):
    def __init__(self):
        super().__init__()
        self.flatten = nn.Flatten()
        self.linear_relu_stack = nn.Sequential(
            nn.Linear(3, 1),
            nn.ReLU(),
            nn.Linear(3, 1),
            nn.ReLU(),
            nn.Linear(3, 1),
        )

    def forward(self, x):
        x = self.flatten(x)
        logits = self.linear_relu_stack(x)
        return logits

# %%
model = NeuralNetwork().to(device)
print(model)
# Out:
# NeuralNetwork(
#   (flatten): Flatten(start_dim=1, end_dim=-1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=3, out_features=1, bias=True)
#     (1): ReLU()
#     (2): Linear(in_features=3, out_features=1, bias=True)
#     (3): ReLU()
#     (4): Linear(in_features=3, out_features=1, bias=True)
#   )
# )

# %% [markdown]
# ## Histogram-Based Gradient Boosted Tree
# - [scikit-learn tutorial](https://scikit-learn.org/stable/modules/ensemble.html#histogram-based-gradient-boosting)
# - [regressor API reference](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.HistGradientBoostingRegressor.html#sklearn.ensemble.HistGradientBoostingRegressor)

# %%
from sklearn.ensemble import HistGradientBoostingRegressor
from sklearn.multioutput import MultiOutputRegressor
from sklearn.model_selection import cross_validate

hgbt = MultiOutputRegressor(HistGradientBoostingRegressor(random_state=0))
regression = hgbt.fit(X_train, y_train)

# %%
regression.score(X_test, y_test)
# Out:
# 0.02750393523022369
